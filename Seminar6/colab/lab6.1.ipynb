# %% [markdown]
# High Performance Python
# =======
#
# Lecture 8. Numba
# ----------
#
# Heavily based on (forked):
#
# Scipy2017 tutorial by Gil Forsyth:
#
# https://github.com/gforsyth/numba_tutorial_scipy2017
#
# https://www.youtube.com/watch?v=1AwG0T4gaO0&t=1349s
#
# GTC2018 tutorial by Stan Seibert:
#
# https://github.com/ContinuumIO/gtc2018-numba

# %% [markdown]
# High Performance Python
# ----------------------
#
# * multiprocessing
# * mpi4py
# * pycuda
# * cupy
# * pyopencl
# * **numba**

# %%
2341287430918682137649812736498176149823746918273469182736498172364981762394871263948716239847612983476192834671982374619827346918273641982736419827367491827364182736498127364981726349817263498716239847612398746 * 102983471023874109238741092837401928374091283740129837409128374012837409129387409182734091837
# Out:
# 

# %% [markdown]
# Numba is:
#
# Just-In-Time (JIT) compiler:
# * generates optimized machine code using LLVM
# * integrates well with Scientific Python stack
# * **function compiler**: Numba compiles Python functions (not entire applications and not parts of functions). Numba is a Python module.
# * **type-specializing**: Numba speeds up your function by generating a specialized implementation for the specific data types you are using.
# * **just-in-time**: Numba translates functions when they are first called so that the compiler knows the argument types. Works in Jupyter notebook.
# * **numerically-focused**: „mostly“ int, float, complex. Works good with numpy arrays.
#
#
# AOT

# %% [markdown]
# The first step is always to find the bottlenecks in your code, via _profiling_: analyzing your code by measuring the execution time of its parts.
#
#
# Tools:
# ------
#
# 2. `cProfile`
# 4. `snakeviz`
# 1. [`line_profiler`](https://github.com/rkern/line_profiler)
# 3. `timeit`
#
#
#
# ```console
# pip install line_profiler
# ```

# %%
import numpy
from time import sleep

def sleepy(time2sleep):
    sleep(time2sleep)

def supersleepy(time2sleep):
    sleep(time2sleep)

def randmatmul(n=1000):
    a = numpy.random.random((n,n))
    b = a @ a
    return b

def useless(a):
    if not isinstance(a, int):
        return

    randmatmul(a)

    ans = 0
    for i in range(a):
        ans += i

    sleepy(1.0)
    supersleepy(2.0)

    return ans

# %% [markdown]
# ## using `cProfile`
#
# [`cProfile`](https://docs.python.org/3.4/library/profile.html#module-cProfile) is the built-in profiler in Python (available since Python 2.5).  It provides a function-by-function report of execution time. First import the module, then usage is simply a call to `cProfile.run()` with your code as argument. It will print out a list of all the functions that were called, with the number of calls and the time spent in each.

# %%
import cProfile

cProfile.run('useless(3000)')

# %% [markdown]
# ## using `snakeviz`

# %%
# %load_ext snakeviz

# %%
# %snakeviz useless(3000)

# %% [markdown]
# ## using `line_profiler`
#
# `line_profiler` offers more granular information than `cProfile`: it will give timing information about each line of code in a profiled function.
#
# ### For a pop-up window with results in notebook:
#
# IPython has an `%lprun` magic to profile specific functions within an executed statement. Usage:
# `%lprun -f func_to_profile <statement>` (get more help by running `%lprun?` in IPython).

# %%
# %load_ext line_profiler
# %lprun -f sleepy -f supersleepy useless(1000)

# %% [markdown]
# ### Write results to a text file

# %%
# %lprun -T timings.txt -f sleepy useless(1000)

# %% [markdown]
# ## Profiling on the command line
#
# Open file, add `@profile` decorator to any function you want to profile, then run
#
# ```console
# kernprof -l script_to_profile.py
# ```
#
# which will generate `script_to_profile.py.lprof` (pickled result).  To view the results, run
#
# ```console
# python -m line_profiler script_to_profile.py.lprof
# ```

# %%
from IPython.display import IFrame
IFrame('http://localhost:8888/terminals/1', width=800, height=700)
# Out:
#         <iframe
#             width="800"
#             height="700"
#             src="http://localhost:8888/terminals/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## `timeit`
#
# ```python
# python -m timeit "print(42)"
# ```

# %%
# !lscpu
# Out:
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              2
# On-line CPU(s) list: 0,1
# Thread(s) per core:  2
# Core(s) per socket:  1
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               79
# Model name:          Intel(R) Xeon(R) CPU @ 2.20GHz
# Stepping:            0
# CPU MHz:             2199.998
# BogoMIPS:            4399.99
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            56320K
# NUMA node0 CPU(s):   0,1
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities

# %%
# line magic
# %timeit x=10
# Out:
# 20.5 ns ± 0.154 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
# %%timeit
# cell magic

x=10
a='hello'
d=[1,2,3]
# Out:
# 76.4 ns ± 0.997 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# JIT
# ===
#
# ### Array sum
#
# The function below is a naive `sum` function that sums all the elements of a given array.

# %%
def sum_array(inp):
    J, I = inp.shape

    #this is a bad idea
    mysum = 0
    for j in range(J):
        for i in range(I):
            mysum += inp[j, i]

    return mysum

# %%
import numpy
arr = numpy.random.random((300, 300))

sum_array(arr)

plain = %timeit -o sum_array(arr)
# Out:
# 20.4 ms ± 615 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
from numba import jit

sum_array_numba = jit()(sum_array)

sum_array_numba(arr)

jitted = %timeit -o sum_array_numba(arr)

plain.best / jitted.best
# Out:
# 141 µs ± 2.06 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 141.59957032021785

# %% [markdown]
# ## More commonly as a decorator

# %%
@jit
def sum_array(inp):
    I, J = inp.shape

    mysum = 0
    for i in range(I):
        for j in range(J):
            mysum += inp[i, j]

    return mysum

# %%
# %timeit arr.sum()
# Out:
# 44.7 µs ± 13.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit numpy.sum(arr)
# Out:
# 52.7 µs ± 12.7 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# Exercise 1. JIT the Mandelbrot fractal
# --------------------------------------------
#
# Separate exercise notebook or use your own Mandelbrot code
#
# 1. Profile the code, find the bottlenecks
# 2. Use Numba to speed up the code
# 3. Compare the timing

# %%
@jit
def add(a, b):
    return a + b


#def prod(a,b):
#    return a*b

# %%
# %%timeit -r 1
add(1, 1)
# Out:
# 535 ns ± 0 ns per loop (mean ± std. dev. of 1 run, 1000000 loops each)

# %% [markdown]
# Numba examines Python bytecode and then translates this into an 'intermediate representation'.  To view this IR, run (compile) `add` and you can access the `inspect_types` method.

# %%
add.inspect_types()
# Out:
# add (int64, int64)
# --------------------------------------------------------------------------------
# # File: <ipython-input-10-485ff261912d>
# # --- LINE 1 ---
#
# @jit
#
# # --- LINE 2 ---
#
# def add(a, b):
#
#     # --- LINE 3 ---
#     # label 0
#     #   a = arg(0, name=a)  :: int64
#     #   b = arg(1, name=b)  :: int64
#     #   $6binary_add.2 = a + b  :: int64
#     #   del b
#     #   del a
#     #   $8return_value.3 = cast(value=$6binary_add.2)  :: int64
#     #   del $6binary_add.2
#     #   return $8return_value.3
#
#     return a + b
#
#
# ================================================================================

# %%
import pprint
pprint.pprint(add.inspect_asm())
# Out:
# {(int64, int64): '\t.text\n'
#                  '\t.file\t"<string>"\n'
#                  '\t.globl\t'
#                  '_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\t.p2align\t4, 0x90\n'
#                  '\t.type\t'
#                  '_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,@function\n'
#                  '_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx:\n'
#                  '\taddq\t%rcx, %rdx\n'
#                  '\tmovq\t%rdx, (%rdi)\n'
#                  '\txorl\t%eax, %eax\n'
#                  '\tretq\n'
#                  '.Lfunc_end0:\n'
#                  '\t.size\t'
#                  '_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '.Lfunc_end0-_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\n'
#                  '\t.globl\t'
#                  '_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\t.p2align\t4, 0x90\n'
#                  '\t.type\t'
#                  '_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,@function\n'
#                  '_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx:\n'
#                  '\t.cfi_startproc\n'
#                  '\tpushq\t%rbp\n'
#                  '\t.cfi_def_cfa_offset 16\n'
#                  '\tpushq\t%r15\n'
#                  '\t.cfi_def_cfa_offset 24\n'
#                  '\tpushq\t%r14\n'
#                  '\t.cfi_def_cfa_offset 32\n'
#                  '\tpushq\t%r13\n'
#                  '\t.cfi_def_cfa_offset 40\n'
#                  '\tpushq\t%r12\n'
#                  '\t.cfi_def_cfa_offset 48\n'
#                  '\tpushq\t%rbx\n'
#                  '\t.cfi_def_cfa_offset 56\n'
#                  '\tsubq\t$24, %rsp\n'
#                  '\t.cfi_def_cfa_offset 80\n'
#                  '\t.cfi_offset %rbx, -56\n'
#                  '\t.cfi_offset %r12, -48\n'
#                  '\t.cfi_offset %r13, -40\n'
#                  '\t.cfi_offset %r14, -32\n'
#                  '\t.cfi_offset %r15, -24\n'
#                  '\t.cfi_offset %rbp, -16\n'
#                  '\tmovq\t%rsi, %rdi\n'
#                  '\tmovabsq\t$.const.add, %rsi\n'
#                  '\tmovabsq\t$PyArg_UnpackTuple, %rbp\n'
#                  '\tleaq\t16(%rsp), %r8\n'
#                  '\tleaq\t8(%rsp), %r9\n'
#                  '\tmovl\t$2, %edx\n'
#                  '\tmovl\t$2, %ecx\n'
#                  '\txorl\t%eax, %eax\n'
#                  '\tcallq\t*%rbp\n'
#                  '\tmovq\t$0, (%rsp)\n'
#                  '\ttestl\t%eax, %eax\n'
#                  '\tje\t.LBB1_1\n'
#                  '\tmovabsq\t'
#                  '$_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '%rax\n'
#                  '\tcmpq\t$0, (%rax)\n'
#                  '\tje\t.LBB1_4\n'
#                  '\tmovq\t16(%rsp), %rdi\n'
#                  '\tmovabsq\t$PyNumber_Long, %r13\n'
#                  '\tcallq\t*%r13\n'
#                  '\tmovabsq\t$PyLong_AsLongLong, %r15\n'
#                  '\tmovabsq\t$Py_DecRef, %r12\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tje\t.LBB1_6\n'
#                  '\tmovq\t%rax, %rbx\n'
#                  '\tmovq\t%rax, %rdi\n'
#                  '\tcallq\t*%r15\n'
#                  '\tmovq\t%rax, %r14\n'
#                  '\tmovq\t%rbx, %rdi\n'
#                  '\tcallq\t*%r12\n'
#                  '\tmovabsq\t$PyErr_Occurred, %rbp\n'
#                  '\tcallq\t*%rbp\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tjne\t.LBB1_1\n'
#                  '.LBB1_9:\n'
#                  '\tmovq\t8(%rsp), %rdi\n'
#                  '\tcallq\t*%r13\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tje\t.LBB1_10\n'
#                  '\tmovq\t%rax, %rbx\n'
#                  '\tmovq\t%rax, %rdi\n'
#                  '\tcallq\t*%r15\n'
#                  '\tmovq\t%rax, %r15\n'
#                  '\tmovq\t%rbx, %rdi\n'
#                  '\tcallq\t*%r12\n'
#                  '\tcallq\t*%rbp\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tjne\t.LBB1_1\n'
#                  '.LBB1_13:\n'
#                  '\tmovq\t$0, (%rsp)\n'
#                  '\tmovabsq\t'
#                  '$_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '%rax\n'
#                  '\tmovq\t%rsp, %rdi\n'
#                  '\tmovq\t%r14, %rdx\n'
#                  '\tmovq\t%r15, %rcx\n'
#                  '\tcallq\t*%rax\n'
#                  '\tmovq\t(%rsp), %rdi\n'
#                  '\tmovabsq\t$PyLong_FromLongLong, %rax\n'
#                  '\tcallq\t*%rax\n'
#                  '.LBB1_2:\n'
#                  '\taddq\t$24, %rsp\n'
#                  '\t.cfi_def_cfa_offset 56\n'
#                  '\tpopq\t%rbx\n'
#                  '\t.cfi_def_cfa_offset 48\n'
#                  '\tpopq\t%r12\n'
#                  '\t.cfi_def_cfa_offset 40\n'
#                  '\tpopq\t%r13\n'
#                  '\t.cfi_def_cfa_offset 32\n'
#                  '\tpopq\t%r14\n'
#                  '\t.cfi_def_cfa_offset 24\n'
#                  '\tpopq\t%r15\n'
#                  '\t.cfi_def_cfa_offset 16\n'
#                  '\tpopq\t%rbp\n'
#                  '\t.cfi_def_cfa_offset 8\n'
#                  '\tretq\n'
#                  '.LBB1_4:\n'
#                  '\t.cfi_def_cfa_offset 80\n'
#                  '\tmovabsq\t$PyExc_RuntimeError, %rdi\n'
#                  '\tmovabsq\t$".const.missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx", '
#                  '%rsi\n'
#                  '\tmovabsq\t$PyErr_SetString, %rax\n'
#                  '\tcallq\t*%rax\n'
#                  '.LBB1_1:\n'
#                  '\txorl\t%eax, %eax\n'
#                  '\tjmp\t.LBB1_2\n'
#                  '.LBB1_6:\n'
#                  '\txorl\t%r14d, %r14d\n'
#                  '\tmovabsq\t$PyErr_Occurred, %rbp\n'
#                  '\tcallq\t*%rbp\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tje\t.LBB1_9\n'
#                  '\tjmp\t.LBB1_1\n'
#                  '.LBB1_10:\n'
#                  '\txorl\t%r15d, %r15d\n'
#                  '\tcallq\t*%rbp\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tje\t.LBB1_13\n'
#                  '\tjmp\t.LBB1_1\n'
#                  '.Lfunc_end1:\n'
#                  '\t.size\t'
#                  '_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '.Lfunc_end1-_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\t.cfi_endproc\n'
#                  '\n'
#                  '\t.globl\t'
#                  'cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\t.p2align\t4, 0x90\n'
#                  '\t.type\t'
#                  'cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,@function\n'
#                  'cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx:\n'
#                  '\tpushq\t%rax\n'
#                  '\tmovq\t%rsi, %rcx\n'
#                  '\tmovq\t%rdi, %rdx\n'
#                  '\tmovq\t$0, (%rsp)\n'
#                  '\tmovabsq\t'
#                  '$_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '%rax\n'
#                  '\tmovq\t%rsp, %rdi\n'
#                  '\tcallq\t*%rax\n'
#                  '\tmovq\t(%rsp), %rax\n'
#                  '\tpopq\t%rcx\n'
#                  '\tretq\n'
#                  '.Lfunc_end2:\n'
#                  '\t.size\t'
#                  'cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '.Lfunc_end2-cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\n'
#                  '\t.type\t'
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,@object\n'
#                  '\t.comm\t'
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,8,8\n'
#                  '\t.type\t.const.add,@object\n'
#                  '\t.section\t.rodata,"a",@progbits\n'
#                  '.const.add:\n'
#                  '\t.asciz\t"add"\n'
#                  '\t.size\t.const.add, 4\n'
#                  '\n'
#                  '\t.type\t".const.missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx",@object\n'
#                  '\t.p2align\t4\n'
#                  '".const.missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx":\n'
#                  '\t.asciz\t"missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx"\n'
#                  '\t.size\t".const.missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx", '
#                  '102\n'
#                  '\n'
#                  '\t.section\t".note.GNU-stack","",@progbits\n'}

# %%
add(1., 1.)
# Out:
# 2.0

# %%
add.inspect_types()
# Out:
# add (int64, int64)
# --------------------------------------------------------------------------------
# # File: <ipython-input-10-485ff261912d>
# # --- LINE 1 ---
#
# @jit
#
# # --- LINE 2 ---
#
# def add(a, b):
#
#     # --- LINE 3 ---
#     # label 0
#     #   a = arg(0, name=a)  :: int64
#     #   b = arg(1, name=b)  :: int64
#     #   $6binary_add.2 = a + b  :: int64
#     #   del b
#     #   del a
#     #   $8return_value.3 = cast(value=$6binary_add.2)  :: int64
#     #   del $6binary_add.2
#     #   return $8return_value.3
#
#     return a + b
#
#
# ================================================================================
# add (float64, float64)
# --------------------------------------------------------------------------------
# # File: <ipython-input-10-485ff261912d>
# # --- LINE 1 ---
#
# @jit
#
# # --- LINE 2 ---
#
# def add(a, b):
#
#     # --- LINE 3 ---
#     # label 0
#     #   a = arg(0, name=a)  :: float64
#     #   b = arg(1, name=b)  :: float64
#     #   $6binary_add.2 = a + b  :: float64
#     #   del b
#     #   del a
#     #   $8return_value.3 = cast(value=$6binary_add.2)  :: float64
#     #   del $6binary_add.2
#     #   return $8return_value.3
#
#     return a + b
#
#
# ================================================================================

# %%
add("Hello ", "World!")
# Out:
# 'Hello World!'

# %%
add.inspect_types()
# Out:
# add (int64, int64)
# --------------------------------------------------------------------------------
# # File: <ipython-input-10-485ff261912d>
# # --- LINE 1 ---
#
# @jit
#
# # --- LINE 2 ---
#
# def add(a, b):
#
#     # --- LINE 3 ---
#     # label 0
#     #   a = arg(0, name=a)  :: int64
#     #   b = arg(1, name=b)  :: int64
#     #   $6binary_add.2 = a + b  :: int64
#     #   del b
#     #   del a
#     #   $8return_value.3 = cast(value=$6binary_add.2)  :: int64
#     #   del $6binary_add.2
#     #   return $8return_value.3
#
#     return a + b
#
#
# ================================================================================
# add (float64, float64)
# --------------------------------------------------------------------------------
# # File: <ipython-input-10-485ff261912d>
# # --- LINE 1 ---
#
# @jit
#
# # --- LINE 2 ---
#
# def add(a, b):
#
#     # --- LINE 3 ---
#     # label 0
#     #   a = arg(0, name=a)  :: float64
#     #   b = arg(1, name=b)  :: float64
#     #   $6binary_add.2 = a + b  :: float64
#     #   del b
#     #   del a
#     #   $8return_value.3 = cast(value=$6binary_add.2)  :: float64
#     #   del $6binary_add.2
#     #   return $8return_value.3
#
#     return a + b
#
#
# ================================================================================
# add (unicode_type, unicode_type)
# --------------------------------------------------------------------------------
# # File: <ipython-input-10-485ff261912d>
# # --- LINE 1 ---
#
# @jit
#
# # --- LINE 2 ---
#
# def add(a, b):
#
#     # --- LINE 3 ---
#     # label 0
#     #   a = arg(0, name=a)  :: unicode_type
#     #   b = arg(1, name=b)  :: unicode_type
#     #   $6binary_add.2 = a + b  :: unicode_type
#     #   del b
#     #   del a
#     #   $8return_value.3 = cast(value=$6binary_add.2)  :: unicode_type
#     #   del $6binary_add.2
#     #   return $8return_value.3
#
#     return a + b
#
#
# ================================================================================

# %% [markdown]
# Ok.  Numba is has correctly inferred the type of the arguments, defining things as `int64` and running smoothly.
#
# (What happens if you do `add(1., 1.)` and then `inspect_types`?)

# %%
add(1.,1.)
# Out:
# 2.0

# %%
import pprint

# %%
pprint.pprint(add.inspect_asm())
# Out:
# {(unicode_type, unicode_type): '\t.text\n'
#                                '\t.file\t"<string>"\n'
#                                '\t.globl\t'
#                                '_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type\n'
#                                '\t.p2align\t4, 0x90\n'
#                                '\t.type\t'
#                                '_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type,@function\n'
#                                '_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type:\n'
#                                '\t.cfi_startproc\n'
#                                '\tpushq\t%rbp\n'
#                                '\t.cfi_def_cfa_offset 16\n'
#                                '\t.cfi_offset %rbp, -16\n'
#                                '\tmovq\t%rsp, %rbp\n'
#                                '\t.cfi_def_cfa_register %rbp\n'
#                                '\tpushq\t%r14\n'
#                                '\tpushq\t%rbx\n'
#                                '\tandq\t$-32, %rsp\n'
#                                '\tsubq\t$160, %rsp\n'
#                                '\t.cfi_offset %rbx, -32\n'
#                                '\t.cfi_offset %r14, -24\n'
#                                '\tmovq\t%rsi, %r14\n'
#                                '\tmovq\t%rdi, %rbx\n'
#                                '\tvmovups\t16(%rbp), %ymm0\n'
#                                '\tmovq\t48(%rbp), %r10\n'
#                                '\tmovl\t56(%rbp), %esi\n'
#                                '\tmovl\t64(%rbp), %edi\n'
#                                '\tvmovups\t72(%rbp), %xmm1\n'
#                                '\tmovq\t88(%rbp), %rax\n'
#                                '\tmovq\t$0, 88(%rsp)\n'
#                                '\tvxorps\t%xmm2, %xmm2, %xmm2\n'
#                                '\tvmovaps\t%ymm2, 96(%rsp)\n'
#                                '\tvmovups\t%ymm2, 112(%rsp)\n'
#                                '\tmovq\t%rax, 72(%rsp)\n'
#                                '\tvmovups\t%xmm1, 56(%rsp)\n'
#                                '\tmovl\t%edi, 48(%rsp)\n'
#                                '\tmovl\t%esi, 40(%rsp)\n'
#                                '\tmovq\t%r10, 32(%rsp)\n'
#                                '\tvmovups\t%ymm0, (%rsp)\n'
#                                '\tmovabsq\t'
#                                '$_ZN5numba7cpython7unicode14unicode_concat12_3clocals_3e11concat_implB2v5B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type12unicode_type, '
#                                '%rax\n'
#                                '\tleaq\t96(%rsp), %rdi\n'
#                                '\tleaq\t88(%rsp), %rsi\n'
#                                '\tvzeroupper\n'
#                                '\tcallq\t*%rax\n'
#                                '\tcmpl\t$-2, %eax\n'
#                                '\tje\t.LBB0_4\n'
#                                '\ttestl\t%eax, %eax\n'
#                                '\tjne\t.LBB0_2\n'
#                                '.LBB0_4:\n'
#                                '\tvmovaps\t96(%rsp), %xmm0\n'
#                                '\tmovq\t112(%rsp), %rax\n'
#                                '\tvmovups\t120(%rsp), %xmm1\n'
#                                '\tmovq\t136(%rsp), %rcx\n'
#                                '\tvmovups\t%xmm0, (%rbx)\n'
#                                '\tmovq\t%rax, 16(%rbx)\n'
#                                '\tvmovups\t%xmm1, 24(%rbx)\n'
#                                '\tmovq\t%rcx, 40(%rbx)\n'
#                                '\txorl\t%eax, %eax\n'
#                                '\tjmp\t.LBB0_3\n'
#                                '.LBB0_2:\n'
#                                '\tmovq\t88(%rsp), %rcx\n'
#                                '\tmovq\t%rcx, (%r14)\n'
#                                '.LBB0_3:\n'
#                                '\tleaq\t-16(%rbp), %rsp\n'
#                                '\tpopq\t%rbx\n'
#                                '\tpopq\t%r14\n'
#                                '\tpopq\t%rbp\n'
#                                '\t.cfi_def_cfa %rsp, 8\n'
#                                '\tretq\n'
#                                '.Lfunc_end0:\n'
#                                '\t.size\t'
#                                '_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type, '
#                                '.Lfunc_end0-_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type\n'
#                                '\t.cfi_endproc\n'
#                                '\n'
#                                '\t.globl\t'
#                                '_ZN7cpython8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type\n'
#                                '\t.p2align\t4, 0x90\n'
#                                '\t.type\t'
#                                '_ZN7cpython8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type,@function\n'
#                                '_ZN7cpython8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type:\n'
#                                '\t.cfi_startproc\n'
#                                '\tpushq\t%rbp\n'
#                                '\t.cfi_def_cfa_offset 16\n'
#                                '\t.cfi_offset %rbp, -16\n'
#                                '\tmovq\t%rsp, %rbp\n'
#                                '\t.cfi_def_cfa_register %rbp\n'
#                                '\tpushq\t%r15\n'
#                                '\tpushq\t%r14\n'
#                                '\tpushq\t%r13\n'
#                                '\tpushq\t%r12\n'
#                                '\tpushq\t%rbx\n'
#                                '\tandq\t$-32, %rsp\n'
#                                '\tsubq\t$256, %rsp\n'
#                                '\t.cfi_offset %rbx, -56\n'
#                                '\t.cfi_offset %r12, -48\n'
#                                '\t.cfi_offset %r13, -40\n'
#                                '\t.cfi_offset %r14, -32\n'
#                                '\t.cfi_offset %r15, -24\n'
#                                '\tmovq\t%rsi, %rdi\n'
#                                '\tmovabsq\t$.const.add, %rsi\n'
#                                '\tmovabsq\t$PyArg_UnpackTuple, %rbx\n'
#                                '\tleaq\t152(%rsp), %r8\n'
#                                '\tleaq\t144(%rsp), %r9\n'
#                                '\tmovl\t$2, %edx\n'
#                                '\tmovl\t$2, %ecx\n'
#                                '\txorl\t%eax, %eax\n'
#                                '\tcallq\t*%rbx\n'
#                                '\tmovq\t$0, 104(%rsp)\n'
#                                '\tmovl\t$0, 28(%rsp)\n'
#                                '\tmovl\t$0, 24(%rsp)\n'
#                                '\tmovq\t$0, 96(%rsp)\n'
#                                '\tmovq\t$0, 88(%rsp)\n'
#                                '\tmovl\t$0, 20(%rsp)\n'
#                                '\tmovl\t$0, 16(%rsp)\n'
#                                '\tmovq\t$0, 80(%rsp)\n'
#                                '\tvxorps\t%xmm0, %xmm0, %xmm0\n'
#                                '\tvmovaps\t%ymm0, 160(%rsp)\n'
#                                '\tvmovups\t%ymm0, 176(%rsp)\n'
#                                '\tmovq\t$0, 72(%rsp)\n'
#                                '\ttestl\t%eax, %eax\n'
#                                '\tje\t.LBB1_1\n'
#                                '\tmovabsq\t'
#                                '$_ZN08NumbaEnv8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type, '
#                                '%rax\n'
#                                '\tcmpq\t$0, (%rax)\n'
#                                '\tje\t.LBB1_4\n'
#                                '\tmovq\t152(%rsp), %r15\n'
#                                '\tmovabsq\t$numba_extract_unicode, %r14\n'
#                                '\tleaq\t104(%rsp), %rsi\n'
#                                '\tleaq\t28(%rsp), %rdx\n'
#                                '\tleaq\t24(%rsp), %rcx\n'
#                                '\tleaq\t96(%rsp), %r8\n'
#                                '\tmovq\t%r15, %rdi\n'
#                                '\tvzeroupper\n'
#                                '\tcallq\t*%r14\n'
#                                '\tmovq\t%rax, %rdi\n'
#                                '\tmovq\t104(%rsp), %rax\n'
#                                '\tmovq\t%rax, 56(%rsp)\n'
#                                '\tmovl\t28(%rsp), %eax\n'
#                                '\tmovl\t%eax, 48(%rsp)\n'
#                                '\tmovl\t24(%rsp), %eax\n'
#                                '\tmovl\t%eax, 40(%rsp)\n'
#                                '\tmovq\t96(%rsp), %r13\n'
#                                '\tmovabsq\t$NRT_meminfo_new_from_pyobject, '
#                                '%r12\n'
#                                '\tmovq\t%rdi, 32(%rsp)\n'
#                                '\tmovq\t%r15, %rsi\n'
#                                '\tcallq\t*%r12\n'
#                                '\tmovq\t%rax, %rbx\n'
#                                '\tmovabsq\t$PyErr_Occurred, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\ttestq\t%rax, %rax\n'
#                                '\tjne\t.LBB1_1\n'
#                                '\tmovq\t%r13, 136(%rsp)\n'
#                                '\tmovq\t%rbx, 64(%rsp)\n'
#                                '\tmovq\t144(%rsp), %r13\n'
#                                '\tleaq\t88(%rsp), %rsi\n'
#                                '\tleaq\t20(%rsp), %rdx\n'
#                                '\tleaq\t16(%rsp), %rcx\n'
#                                '\tleaq\t80(%rsp), %r8\n'
#                                '\tmovq\t%r13, %rdi\n'
#                                '\tcallq\t*%r14\n'
#                                '\tmovq\t%rax, %r14\n'
#                                '\tmovq\t88(%rsp), %rax\n'
#                                '\tmovq\t%rax, 128(%rsp)\n'
#                                '\tmovl\t20(%rsp), %eax\n'
#                                '\tmovq\t%rax, 120(%rsp)\n'
#                                '\tmovl\t16(%rsp), %eax\n'
#                                '\tmovq\t%rax, 112(%rsp)\n'
#                                '\tmovq\t80(%rsp), %rbx\n'
#                                '\tmovq\t%r14, %rdi\n'
#                                '\tmovq\t%r13, %rsi\n'
#                                '\tcallq\t*%r12\n'
#                                '\tmovq\t%rax, %r12\n'
#                                '\tmovabsq\t$PyErr_Occurred, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\ttestq\t%rax, %rax\n'
#                                '\tjne\t.LBB1_8\n'
#                                '\tvxorps\t%xmm0, %xmm0, %xmm0\n'
#                                '\tvmovups\t%ymm0, 176(%rsp)\n'
#                                '\tvmovaps\t%ymm0, 160(%rsp)\n'
#                                '\tmovabsq\t'
#                                '$_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type, '
#                                '%rax\n'
#                                '\tleaq\t160(%rsp), %rdi\n'
#                                '\tleaq\t72(%rsp), %rsi\n'
#                                '\tmovq\t32(%rsp), %rdx\n'
#                                '\tmovq\t56(%rsp), %rcx\n'
#                                '\tmovl\t48(%rsp), %r8d\n'
#                                '\tmovl\t40(%rsp), %r9d\n'
#                                '\tpushq\t%r13\n'
#                                '\tpushq\t%r12\n'
#                                '\tpushq\t%rbx\n'
#                                '\tpushq\t136(%rsp)\n'
#                                '\tpushq\t152(%rsp)\n'
#                                '\tpushq\t168(%rsp)\n'
#                                '\tpushq\t%r14\n'
#                                '\tpushq\t%r15\n'
#                                '\tmovq\t128(%rsp), %r15\n'
#                                '\tpushq\t%r15\n'
#                                '\tpushq\t208(%rsp)\n'
#                                '\tvzeroupper\n'
#                                '\tcallq\t*%rax\n'
#                                '\taddq\t$80, %rsp\n'
#                                '\tmovl\t%eax, %ebx\n'
#                                '\tmovq\t72(%rsp), %rax\n'
#                                '\tmovq\t%rax, 32(%rsp)\n'
#                                '\tmovq\t160(%rsp), %rax\n'
#                                '\tmovq\t%rax, 48(%rsp)\n'
#                                '\tmovq\t168(%rsp), %rax\n'
#                                '\tmovq\t%rax, 40(%rsp)\n'
#                                '\tmovl\t176(%rsp), %r14d\n'
#                                '\tmovq\t192(%rsp), %rax\n'
#                                '\tmovq\t%rax, 56(%rsp)\n'
#                                '\tmovabsq\t$NRT_decref, %r13\n'
#                                '\tmovq\t%r15, %rdi\n'
#                                '\tcallq\t*%r13\n'
#                                '\tmovq\t%r12, %rdi\n'
#                                '\tcallq\t*%r13\n'
#                                '\tcmpl\t$-2, %ebx\n'
#                                '\tje\t.LBB1_14\n'
#                                '\ttestl\t%ebx, %ebx\n'
#                                '\tjne\t.LBB1_11\n'
#                                '\tmovabsq\t$PyUnicode_FromKindAndData, %rax\n'
#                                '\tmovl\t%r14d, %edi\n'
#                                '\tmovq\t48(%rsp), %rsi\n'
#                                '\tmovq\t40(%rsp), %rdx\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovq\t%rax, %rbx\n'
#                                '\tmovabsq\t$PyObject_Hash, %rax\n'
#                                '\tmovq\t%rbx, %rdi\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovq\t56(%rsp), %rdi\n'
#                                '\tcallq\t*%r13\n'
#                                '\tmovq\t%rbx, %rax\n'
#                                '\tjmp\t.LBB1_2\n'
#                                '.LBB1_14:\n'
#                                '\tmovabsq\t$_Py_NoneStruct, %rbx\n'
#                                '\tmovabsq\t$Py_IncRef, %rax\n'
#                                '\tmovq\t%rbx, %rdi\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovq\t%rbx, %rax\n'
#                                '\tjmp\t.LBB1_2\n'
#                                '.LBB1_11:\n'
#                                '\tjle\t.LBB1_17\n'
#                                '\tmovabsq\t$PyErr_Clear, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovq\t32(%rsp), %rax\n'
#                                '\tmovq\t16(%rax), %rdx\n'
#                                '\tmovl\t8(%rax), %esi\n'
#                                '\tmovq\t(%rax), %rdi\n'
#                                '\tmovabsq\t$numba_unpickle, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\ttestq\t%rax, %rax\n'
#                                '\tje\t.LBB1_1\n'
#                                '\tmovabsq\t$numba_do_raise, %rcx\n'
#                                '\tmovq\t%rax, %rdi\n'
#                                '\tcallq\t*%rcx\n'
#                                '\tjmp\t.LBB1_1\n'
#                                '.LBB1_17:\n'
#                                '\tcmpl\t$-3, %ebx\n'
#                                '\tje\t.LBB1_20\n'
#                                '\tcmpl\t$-1, %ebx\n'
#                                '\tje\t.LBB1_1\n'
#                                '\tmovabsq\t$PyExc_SystemError, %rdi\n'
#                                '\tmovabsq\t$".const.unknown error when calling '
#                                'native function", %rsi\n'
#                                '\tjmp\t.LBB1_5\n'
#                                '.LBB1_20:\n'
#                                '\tmovabsq\t$PyExc_StopIteration, %rdi\n'
#                                '\tmovabsq\t$PyErr_SetNone, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\tjmp\t.LBB1_1\n'
#                                '.LBB1_4:\n'
#                                '\tmovabsq\t$PyExc_RuntimeError, %rdi\n'
#                                '\tmovabsq\t$".const.missing Environment: '
#                                '_ZN08NumbaEnv8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type", '
#                                '%rsi\n'
#                                '.LBB1_5:\n'
#                                '\tmovabsq\t$PyErr_SetString, %rax\n'
#                                '\tvzeroupper\n'
#                                '\tcallq\t*%rax\n'
#                                '.LBB1_1:\n'
#                                '\txorl\t%eax, %eax\n'
#                                '.LBB1_2:\n'
#                                '\tleaq\t-40(%rbp), %rsp\n'
#                                '\tpopq\t%rbx\n'
#                                '\tpopq\t%r12\n'
#                                '\tpopq\t%r13\n'
#                                '\tpopq\t%r14\n'
#                                '\tpopq\t%r15\n'
#                                '\tpopq\t%rbp\n'
#                                '\t.cfi_def_cfa %rsp, 8\n'
#                                '\tvzeroupper\n'
#                                '\tretq\n'
#                                '.LBB1_8:\n'
#                                '\t.cfi_def_cfa %rbp, 16\n'
#                                '\tmovabsq\t$NRT_decref, %rax\n'
#                                '\tmovq\t64(%rsp), %rdi\n'
#                                '\tcallq\t*%rax\n'
#                                '\tjmp\t.LBB1_1\n'
#                                '.Lfunc_end1:\n'
#                                '\t.size\t'
#                                '_ZN7cpython8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type, '
#                                '.Lfunc_end1-_ZN7cpython8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type\n'
#                                '\t.cfi_endproc\n'
#                                '\n'
#                                '\t.globl\t'
#                                'cfunc._ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type\n'
#                                '\t.p2align\t4, 0x90\n'
#                                '\t.type\t'
#                                'cfunc._ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type,@function\n'
#                                'cfunc._ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type:\n'
#                                '\t.cfi_startproc\n'
#                                '\tpushq\t%rbp\n'
#                                '\t.cfi_def_cfa_offset 16\n'
#                                '\t.cfi_offset %rbp, -16\n'
#                                '\tmovq\t%rsp, %rbp\n'
#                                '\t.cfi_def_cfa_register %rbp\n'
#                                '\tpushq\t%r15\n'
#                                '\tpushq\t%r14\n'
#                                '\tpushq\t%r13\n'
#                                '\tpushq\t%r12\n'
#                                '\tpushq\t%rbx\n'
#                                '\tandq\t$-32, %rsp\n'
#                                '\tsubq\t$224, %rsp\n'
#                                '\t.cfi_offset %rbx, -56\n'
#                                '\t.cfi_offset %r12, -48\n'
#                                '\t.cfi_offset %r13, -40\n'
#                                '\t.cfi_offset %r14, -32\n'
#                                '\t.cfi_offset %r15, -24\n'
#                                '\tmovl\t%r8d, %eax\n'
#                                '\tmovl\t%ecx, %r8d\n'
#                                '\tmovq\t%rdx, %rcx\n'
#                                '\tmovq\t%rsi, %rdx\n'
#                                '\tmovq\t%rdi, %r14\n'
#                                '\tvmovups\t16(%rbp), %ymm0\n'
#                                '\tmovl\t48(%rbp), %esi\n'
#                                '\tmovl\t56(%rbp), %edi\n'
#                                '\tvmovaps\t64(%rbp), %xmm1\n'
#                                '\tvxorps\t%xmm2, %xmm2, %xmm2\n'
#                                '\tvmovups\t%ymm2, 144(%rsp)\n'
#                                '\tmovq\t80(%rbp), %rbx\n'
#                                '\tvmovaps\t%ymm2, 128(%rsp)\n'
#                                '\tmovq\t$0, 96(%rsp)\n'
#                                '\tmovq\t%rbx, 72(%rsp)\n'
#                                '\tvmovups\t%xmm1, 56(%rsp)\n'
#                                '\tmovl\t%edi, 48(%rsp)\n'
#                                '\tmovl\t%esi, 40(%rsp)\n'
#                                '\tvmovups\t%ymm0, 8(%rsp)\n'
#                                '\tmovq\t%r9, (%rsp)\n'
#                                '\tmovabsq\t'
#                                '$_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type, '
#                                '%rbx\n'
#                                '\tleaq\t128(%rsp), %rdi\n'
#                                '\tleaq\t96(%rsp), %rsi\n'
#                                '\tmovl\t%eax, %r9d\n'
#                                '\tvzeroupper\n'
#                                '\tcallq\t*%rbx\n'
#                                '\tmovl\t%eax, %ebx\n'
#                                '\tmovq\t96(%rsp), %r12\n'
#                                '\tmovq\t128(%rsp), %rax\n'
#                                '\tmovq\t136(%rsp), %rcx\n'
#                                '\tmovl\t144(%rsp), %edx\n'
#                                '\tmovl\t148(%rsp), %esi\n'
#                                '\tmovq\t152(%rsp), %rdi\n'
#                                '\tmovq\t160(%rsp), %r13\n'
#                                '\tmovq\t168(%rsp), %r15\n'
#                                '\tmovl\t$0, 84(%rsp)\n'
#                                '\tcmpl\t$-2, %ebx\n'
#                                '\tje\t.LBB2_5\n'
#                                '\ttestl\t%ebx, %ebx\n'
#                                '\tje\t.LBB2_5\n'
#                                '\tmovq\t%rdi, 104(%rsp)\n'
#                                '\tmovl\t%esi, 88(%rsp)\n'
#                                '\tmovl\t%edx, 92(%rsp)\n'
#                                '\tmovq\t%rcx, 112(%rsp)\n'
#                                '\tmovq\t%rax, 120(%rsp)\n'
#                                '\tmovabsq\t$numba_gil_ensure, %rax\n'
#                                '\tleaq\t84(%rsp), %rdi\n'
#                                '\tcallq\t*%rax\n'
#                                '\ttestl\t%ebx, %ebx\n'
#                                '\tjle\t.LBB2_6\n'
#                                '\tmovabsq\t$PyErr_Clear, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovq\t16(%r12), %rdx\n'
#                                '\tmovl\t8(%r12), %esi\n'
#                                '\tmovq\t(%r12), %rdi\n'
#                                '\tmovabsq\t$numba_unpickle, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\ttestq\t%rax, %rax\n'
#                                '\tje\t.LBB2_4\n'
#                                '\tmovabsq\t$numba_do_raise, %rcx\n'
#                                '\tmovq\t%rax, %rdi\n'
#                                '\tcallq\t*%rcx\n'
#                                '.LBB2_4:\n'
#                                '\tmovabsq\t$".const.<numba.core.cpu.CPUContext '
#                                'object at 0x7f3b6561da50>", %rdi\n'
#                                '\tmovabsq\t$PyUnicode_FromString, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovq\t%rax, %rbx\n'
#                                '\tmovabsq\t$PyErr_WriteUnraisable, %rax\n'
#                                '\tmovq\t%rbx, %rdi\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovabsq\t$Py_DecRef, %rax\n'
#                                '\tmovq\t%rbx, %rdi\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovabsq\t$numba_gil_release, %rax\n'
#                                '\tleaq\t84(%rsp), %rdi\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovq\t120(%rsp), %rax\n'
#                                '\tmovq\t112(%rsp), %rcx\n'
#                                '\tmovl\t92(%rsp), %edx\n'
#                                '\tmovl\t88(%rsp), %esi\n'
#                                '\tmovq\t104(%rsp), %rdi\n'
#                                '.LBB2_5:\n'
#                                '\tmovq\t%r15, 40(%r14)\n'
#                                '\tmovq\t%r13, 32(%r14)\n'
#                                '\tmovq\t%rdi, 24(%r14)\n'
#                                '\tmovl\t%esi, 20(%r14)\n'
#                                '\tmovl\t%edx, 16(%r14)\n'
#                                '\tmovq\t%rcx, 8(%r14)\n'
#                                '\tmovq\t%rax, (%r14)\n'
#                                '\tmovq\t%r14, %rax\n'
#                                '\tleaq\t-40(%rbp), %rsp\n'
#                                '\tpopq\t%rbx\n'
#                                '\tpopq\t%r12\n'
#                                '\tpopq\t%r13\n'
#                                '\tpopq\t%r14\n'
#                                '\tpopq\t%r15\n'
#                                '\tpopq\t%rbp\n'
#                                '\t.cfi_def_cfa %rsp, 8\n'
#                                '\tretq\n'
#                                '.LBB2_6:\n'
#                                '\t.cfi_def_cfa %rbp, 16\n'
#                                '\tcmpl\t$-3, %ebx\n'
#                                '\tje\t.LBB2_10\n'
#                                '\tcmpl\t$-1, %ebx\n'
#                                '\tje\t.LBB2_4\n'
#                                '\tmovabsq\t$PyExc_SystemError, %rdi\n'
#                                '\tmovabsq\t$".const.unknown error when calling '
#                                'native function.1", %rsi\n'
#                                '\tmovabsq\t$PyErr_SetString, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\tjmp\t.LBB2_4\n'
#                                '.LBB2_10:\n'
#                                '\tmovabsq\t$PyExc_StopIteration, %rdi\n'
#                                '\tmovabsq\t$PyErr_SetNone, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\tjmp\t.LBB2_4\n'
#                                '.Lfunc_end2:\n'
#                                '\t.size\t'
#                                'cfunc._ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type, '
#                                '.Lfunc_end2-cfunc._ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type\n'
#                                '\t.cfi_endproc\n'
#                                '\n'
#                                '\t.section\t.rodata.cst32,"aM",@progbits,32\n'
#                                '\t.p2align\t5\n'
#                                '.LCPI3_0:\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '\t.short\t255\n'
#                                '.LCPI3_1:\n'
#                                '\t.byte\t0\n'
#                                '\t.byte\t1\n'
#                                '\t.byte\t4\n'
#                                '\t.byte\t5\n'
#                                '\t.byte\t8\n'
#                                '\t.byte\t9\n'
#                                '\t.byte\t12\n'
#                                '\t.byte\t13\n'
#                                '\t.byte\t8\n'
#                                '\t.byte\t9\n'
#                                '\t.byte\t12\n'
#                                '\t.byte\t13\n'
#                                '\t.byte\t12\n'
#                                '\t.byte\t13\n'
#                                '\t.byte\t14\n'
#                                '\t.byte\t15\n'
#                                '\t.byte\t16\n'
#                                '\t.byte\t17\n'
#                                '\t.byte\t20\n'
#                                '\t.byte\t21\n'
#                                '\t.byte\t24\n'
#                                '\t.byte\t25\n'
#                                '\t.byte\t28\n'
#                                '\t.byte\t29\n'
#                                '\t.byte\t24\n'
#                                '\t.byte\t25\n'
#                                '\t.byte\t28\n'
#                                '\t.byte\t29\n'
#                                '\t.byte\t28\n'
#                                '\t.byte\t29\n'
#                                '\t.byte\t30\n'
#                                '\t.byte\t31\n'
#                                '\t.section\t.rodata.cst16,"aM",@progbits,16\n'
#                                '\t.p2align\t4\n'
#                                '.LCPI3_2:\n'
#                                '\t.byte\t0\n'
#                                '\t.byte\t4\n'
#                                '\t.byte\t8\n'
#                                '\t.byte\t12\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.zero\t1\n'
#                                '\t.text\n'
#                                '\t.weak\t'
#                                '_ZN5numba7cpython7unicode14unicode_concat12_3clocals_3e11concat_implB2v5B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type12unicode_type\n'
#                                '\t.p2align\t4, 0x90\n'
#                                '\t.type\t'
#                                '_ZN5numba7cpython7unicode14unicode_concat12_3clocals_3e11concat_implB2v5B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type12unicode_type,@function\n'
#                                '_ZN5numba7cpython7unicode14unicode_concat12_3clocals_3e11concat_implB2v5B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type12unicode_type:\n'
#                                '\t.cfi_startproc\n'
#                                '\tpushq\t%rbp\n'
#                                '\t.cfi_def_cfa_offset 16\n'
#                                '\tpushq\t%r15\n'
#                                '\t.cfi_def_cfa_offset 24\n'
#                                '\tpushq\t%r14\n'
#                                '\t.cfi_def_cfa_offset 32\n'
#                                '\tpushq\t%r13\n'
#                                '\t.cfi_def_cfa_offset 40\n'
#                                '\tpushq\t%r12\n'
#                                '\t.cfi_def_cfa_offset 48\n'
#                                '\tpushq\t%rbx\n'
#                                '\t.cfi_def_cfa_offset 56\n'
#                                '\tsubq\t$56, %rsp\n'
#                                '\t.cfi_def_cfa_offset 112\n'
#                                '\t.cfi_offset %rbx, -56\n'
#                                '\t.cfi_offset %r12, -48\n'
#                                '\t.cfi_offset %r13, -40\n'
#                                '\t.cfi_offset %r14, -32\n'
#                                '\t.cfi_offset %r15, -24\n'
#                                '\t.cfi_offset %rbp, -16\n'
#                                '\tmovl\t%r9d, 44(%rsp)\n'
#                                '\tmovl\t%r8d, %r15d\n'
#                                '\tmovq\t%rcx, %r12\n'
#                                '\tmovq\t%rdx, %r14\n'
#                                '\tmovq\t%rsi, %r13\n'
#                                '\tmovq\t%rdi, 48(%rsp)\n'
#                                '\tmovq\t176(%rsp), %rbx\n'
#                                '\tmovq\t120(%rsp), %rdi\n'
#                                '\tmovabsq\t$NRT_incref, %rbp\n'
#                                '\tcallq\t*%rbp\n'
#                                '\tmovq\t%rbx, %rdi\n'
#                                '\tcallq\t*%rbp\n'
#                                '\tmovabsq\t$.const.picklebuf.139893081784720, '
#                                '%rdx\n'
#                                '\ttestl\t%r15d, %r15d\n'
#                                '\tje\t.LBB3_2\n'
#                                '\tmovl\t152(%rsp), %ebp\n'
#                                '\ttestl\t%ebp, %ebp\n'
#                                '\tjne\t.LBB3_4\n'
#                                '.LBB3_2:\n'
#                                '\tmovq\t%rdx, (%r13)\n'
#                                '\tmovl\t$1, %eax\n'
#                                '.LBB3_3:\n'
#                                '\taddq\t$56, %rsp\n'
#                                '\t.cfi_def_cfa_offset 56\n'
#                                '\tpopq\t%rbx\n'
#                                '\t.cfi_def_cfa_offset 48\n'
#                                '\tpopq\t%r12\n'
#                                '\t.cfi_def_cfa_offset 40\n'
#                                '\tpopq\t%r13\n'
#                                '\t.cfi_def_cfa_offset 32\n'
#                                '\tpopq\t%r14\n'
#                                '\t.cfi_def_cfa_offset 24\n'
#                                '\tpopq\t%r15\n'
#                                '\t.cfi_def_cfa_offset 16\n'
#                                '\tpopq\t%rbp\n'
#                                '\t.cfi_def_cfa_offset 8\n'
#                                '\tvzeroupper\n'
#                                '\tretq\n'
#                                '.LBB3_4:\n'
#                                '\t.cfi_def_cfa_offset 112\n'
#                                '\tmovslq\t%r15d, %rdx\n'
#                                '\tmovl\t%ebp, %ecx\n'
#                                '\tcmpq\t$1, %rdx\n'
#                                '\tje\t.LBB3_8\n'
#                                '\tmovl\t%r15d, %ecx\n'
#                                '\tcmpq\t$4, %rdx\n'
#                                '\tje\t.LBB3_8\n'
#                                '\tcmpq\t$2, %rdx\n'
#                                '\tjne\t.LBB3_16\n'
#                                '\tcmpl\t$4, %ebp\n'
#                                '\tmovl\t%r15d, %ecx\n'
#                                '\tcmovel\t%ebp, %ecx\n'
#                                '.LBB3_8:\n'
#                                '\tmovslq\t%ecx, %rbx\n'
#                                '\tleaq\t-1(%rbx), %rax\n'
#                                '\tcmpq\t$2, %rax\n'
#                                '\tjb\t.LBB3_11\n'
#                                '\ttestq\t%rbx, %rbx\n'
#                                '\tje\t.LBB3_17\n'
#                                '\tcmpq\t$4, %rbx\n'
#                                '\tjne\t.LBB3_18\n'
#                                '.LBB3_11:\n'
#                                '\tmovq\t%rdx, 16(%rsp)\n'
#                                '\tmovl\t%ecx, 12(%rsp)\n'
#                                '\tmovq\t144(%rsp), %rax\n'
#                                '\tleaq\t(%rax,%r12), %rcx\n'
#                                '\tmovq\t%rcx, 24(%rsp)\n'
#                                '\tleaq\t1(%rcx), %rdi\n'
#                                '\timulq\t%rbx, %rdi\n'
#                                '\tmovabsq\t$NRT_MemInfo_alloc_safe, %rax\n'
#                                '\tcallq\t*%rax\n'
#                                '\ttestq\t%rax, %rax\n'
#                                '\tje\t.LBB3_76\n'
#                                '\tmovq\t24(%rax), %rdi\n'
#                                '\tcmpq\t$4, %rbx\n'
#                                '\tje\t.LBB3_19\n'
#                                '\tcmpq\t$2, %rbx\n'
#                                '\tmovq\t16(%rsp), %rcx\n'
#                                '\tje\t.LBB3_20\n'
#                                '\tcmpq\t$1, %rbx\n'
#                                '\tjne\t.LBB3_27\n'
#                                '\tmovq\t%rax, 32(%rsp)\n'
#                                '\tmovq\t24(%rsp), %rax\n'
#                                '\tmovb\t$0, (%rdi,%rax)\n'
#                                '\tjmp\t.LBB3_21\n'
#                                '.LBB3_16:\n'
#                                '\tmovabsq\t$.const.picklebuf.139893081157712, '
#                                '%rdx\n'
#                                '\tjmp\t.LBB3_2\n'
#                                '.LBB3_17:\n'
#                                '\tmovabsq\t$.const.picklebuf.139893080750592, '
#                                '%rdx\n'
#                                '\tjmp\t.LBB3_2\n'
#                                '.LBB3_18:\n'
#                                '\tmovabsq\t$.const.picklebuf.139893080750432, '
#                                '%rdx\n'
#                                '\tjmp\t.LBB3_2\n'
#                                '.LBB3_19:\n'
#                                '\tmovq\t%rax, 32(%rsp)\n'
#                                '\tmovq\t24(%rsp), %rax\n'
#                                '\tmovl\t$0, (%rdi,%rax,4)\n'
#                                '\tmovq\t16(%rsp), %rcx\n'
#                                '\tjmp\t.LBB3_21\n'
#                                '.LBB3_20:\n'
#                                '\tmovq\t%rax, 32(%rsp)\n'
#                                '\tmovq\t24(%rsp), %rax\n'
#                                '\tmovw\t$0, (%rdi,%rax,2)\n'
#                                '.LBB3_21:\n'
#                                '\ttestq\t%r12, %r12\n'
#                                '\tmovq\t%rbx, 16(%rsp)\n'
#                                '\tjle\t.LBB3_119\n'
#                                '\tmovq\t%r12, %rax\n'
#                                '\tsarq\t$63, %rax\n'
#                                '\tandnq\t%r12, %rax, %rax\n'
#                                '\tcmpq\t$1, %rcx\n'
#                                '\tje\t.LBB3_28\n'
#                                '\tcmpq\t$2, %rcx\n'
#                                '\tjne\t.LBB3_31\n'
#                                '\tcmpq\t$1, %rax\n'
#                                '\tmovl\t$1, %r9d\n'
#                                '\tcmovgq\t%r12, %r9\n'
#                                '\tcmpl\t$1, 12(%rsp)\n'
#                                '\tjne\t.LBB3_40\n'
#                                '\tcmpq\t$64, %r9\n'
#                                '\tjb\t.LBB3_26\n'
#                                '\tleaq\t(%r14,%r9,2), %rcx\n'
#                                '\tcmpq\t%rcx, %rdi\n'
#                                '\tjae\t.LBB3_68\n'
#                                '\tleaq\t(%rdi,%r9), %rcx\n'
#                                '\tcmpq\t%r14, %rcx\n'
#                                '\tjbe\t.LBB3_68\n'
#                                '.LBB3_26:\n'
#                                '\txorl\t%ecx, %ecx\n'
#                                '.LBB3_95:\n'
#                                '\tmovq\t%rcx, %rsi\n'
#                                '\tnotq\t%rsi\n'
#                                '\taddq\t%r9, %rsi\n'
#                                '\tmovq\t%r9, %rbx\n'
#                                '\tandq\t$7, %rbx\n'
#                                '\tje\t.LBB3_97\n'
#                                '.LBB3_96:\n'
#                                '\tleaq\t1(%rcx), %rdx\n'
#                                '\tmovzbl\t(%r14,%rcx,2), %eax\n'
#                                '\tmovb\t%al, (%rdi,%rcx)\n'
#                                '\tmovq\t%rdx, %rcx\n'
#                                '\tdecq\t%rbx\n'
#                                '\tjne\t.LBB3_96\n'
#                                '\tjmp\t.LBB3_98\n'
#                                '.LBB3_27:\n'
#                                '\tmovabsq\t$.const.picklebuf.139893080449344, '
#                                '%rdx\n'
#                                '\tjmp\t.LBB3_2\n'
#                                '.LBB3_28:\n'
#                                '\tcmpq\t$1, %rax\n'
#                                '\tmovl\t$1, %r9d\n'
#                                '\tcmovgq\t%r12, %r9\n'
#                                '\tcmpl\t$1, 12(%rsp)\n'
#                                '\tjne\t.LBB3_45\n'
#                                '\tcmpq\t$128, %r9\n'
#                                '\tjb\t.LBB3_30\n'
#                                '\tleaq\t(%r14,%r9), %rcx\n'
#                                '\tcmpq\t%rcx, %rdi\n'
#                                '\tjae\t.LBB3_71\n'
#                                '\tleaq\t(%rdi,%r9), %rcx\n'
#                                '\tcmpq\t%r14, %rcx\n'
#                                '\tjbe\t.LBB3_71\n'
#                                '.LBB3_30:\n'
#                                '\txorl\t%ecx, %ecx\n'
#                                '.LBB3_83:\n'
#                                '\tmovq\t%rcx, %rsi\n'
#                                '\tnotq\t%rsi\n'
#                                '\taddq\t%r9, %rsi\n'
#                                '\tmovq\t%r9, %rbx\n'
#                                '\tandq\t$7, %rbx\n'
#                                '\tje\t.LBB3_85\n'
#                                '.LBB3_84:\n'
#                                '\tleaq\t1(%rcx), %rdx\n'
#                                '\tmovzbl\t(%r14,%rcx), %eax\n'
#                                '\tmovb\t%al, (%rdi,%rcx)\n'
#                                '\tmovq\t%rdx, %rcx\n'
#                                '\tdecq\t%rbx\n'
#                                '\tjne\t.LBB3_84\n'
#                                '\tjmp\t.LBB3_86\n'
#                                '.LBB3_31:\n'
#                                '\tcmpq\t$1, %rax\n'
#                                '\tmovl\t$1, %edx\n'
#                                '\tcmovgq\t%r12, %rdx\n'
#                                '\tcmpl\t$4, %r15d\n'
#                                '\tjne\t.LBB3_53\n'
#                                '\txorl\t%eax, %eax\n'
#                                '\tjmp\t.LBB3_35\n'
#                                '.LBB3_33:\n'
#                                '\tmovb\t%cl, (%rdi,%rax)\n'
#                                '.LBB3_34:\n'
#                                '\tincq\t%rax\n'
#                                '\tcmpq\t%rax, %rdx\n'
#                                '\tje\t.LBB3_119\n'
#                                '.LBB3_35:\n'
#                                '\tmovl\t(%r14,%rax,4), %ecx\n'
#                                '\tcmpq\t$1, %rbx\n'
#                                '\tje\t.LBB3_33\n'
#                                '\tcmpq\t$2, %rbx\n'
#                                '\tje\t.LBB3_39\n'
#                                '\tcmpq\t$4, %rbx\n'
#                                '\tjne\t.LBB3_146\n'
#                                '\tmovl\t%ecx, (%rdi,%rax,4)\n'
#                                '\tjmp\t.LBB3_34\n'
#                                '.LBB3_39:\n'
#                                '\tmovw\t%cx, (%rdi,%rax,2)\n'
#                                '\tjmp\t.LBB3_34\n'
#                                '.LBB3_40:\n'
#                                '\txorl\t%ecx, %ecx\n'
#                                '\tjmp\t.LBB3_42\n'
#                                '.LBB3_41:\n'
#                                '\tmovw\t%dx, (%rdi,%rcx,2)\n'
#                                '\tincq\t%rcx\n'
#                                '\tcmpq\t%rcx, %r9\n'
#                                '\tje\t.LBB3_119\n'
#                                '.LBB3_42:\n'
#                                '\tmovzwl\t(%r14,%rcx,2), %edx\n'
#                                '\tcmpq\t$2, %rbx\n'
#                                '\tje\t.LBB3_41\n'
#                                '\tcmpq\t$4, %rbx\n'
#                                '\tjne\t.LBB3_146\n'
#                                '\tmovzwl\t%dx, %eax\n'
#                                '\tmovl\t%eax, (%rdi,%rcx,4)\n'
#                                '\tincq\t%rcx\n'
#                                '\tcmpq\t%rcx, %r9\n'
#                                '\tjne\t.LBB3_42\n'
#                                '\tjmp\t.LBB3_119\n'
#                                '.LBB3_45:\n'
#                                '\tcmpq\t$4, %rbx\n'
#                                '\tje\t.LBB3_66\n'
#                                '\tcmpq\t$2, %rbx\n'
#                                '\tjne\t.LBB3_146\n'
#                                '\tcmpq\t$63, %r9\n'
#                                '\tjbe\t.LBB3_50\n'
#                                '\tleaq\t(%r14,%r9), %rcx\n'
#                                '\tcmpq\t%rcx, %rdi\n'
#                                '\tjae\t.LBB3_100\n'
#                                '\tleaq\t(%rdi,%r9,2), %rcx\n'
#                                '\tcmpq\t%r14, %rcx\n'
#                                '\tjbe\t.LBB3_100\n'
#                                '.LBB3_50:\n'
#                                '\txorl\t%ecx, %ecx\n'
#                                '.LBB3_51:\n'
#                                '\tmovq\t%rcx, %r8\n'
#                                '\tnotq\t%r8\n'
#                                '\taddq\t%r9, %r8\n'
#                                '\tmovq\t%r9, %rax\n'
#                                '\tandq\t$7, %rax\n'
#                                '\tje\t.LBB3_88\n'
#                                '.LBB3_52:\n'
#                                '\tleaq\t1(%rcx), %rdx\n'
#                                '\tmovzbl\t(%r14,%rcx), %esi\n'
#                                '\tmovw\t%si, (%rdi,%rcx,2)\n'
#                                '\tmovq\t%rdx, %rcx\n'
#                                '\tdecq\t%rax\n'
#                                '\tjne\t.LBB3_52\n'
#                                '\tjmp\t.LBB3_89\n'
#                                '.LBB3_53:\n'
#                                '\tcmpl\t$1, 12(%rsp)\n'
#                                '\tjne\t.LBB3_61\n'
#                                '\tmovabsq\t$memset, %rax\n'
#                                '\txorl\t%esi, %esi\n'
#                                '\tmovq\t%rdi, %rbx\n'
#                                '\tcallq\t*%rax\n'
#                                '\tmovq\t%rbx, %rdi\n'
#                                '\tjmp\t.LBB3_119\n'
#                                '.LBB3_61:\n'
#                                '\txorl\t%eax, %eax\n'
#                                '\tjmp\t.LBB3_63\n'
#                                '.LBB3_62:\n'
#                                '\tmovw\t$0, (%rdi,%rax,2)\n'
#                                '\tincq\t%rax\n'
#                                '\tcmpq\t%rax, %rdx\n'
#                                '\tje\t.LBB3_119\n'
#                                '.LBB3_63:\n'
#                                '\tcmpq\t$2, %rbx\n'
#                                '\tje\t.LBB3_62\n'
#                                '\tcmpq\t$4, %rbx\n'
#                                '\tjne\t.LBB3_146\n'
#                                '\tmovl\t$0, (%rdi,%rax,4)\n'
#                                '\tincq\t%rax\n'
#                                '\tcmpq\t%rax, %rdx\n'
#                                '\tjne\t.LBB3_63\n'
#                                '\tjmp\t.LBB3_119\n'
#                                '.LBB3_66:\n'
#                                '\tcmpq\t$32, %r9\n'
#                                '\tjb\t.LBB3_67\n'
#                                '\tleaq\t(%r14,%r9), %rcx\n'
#                                '\tcmpq\t%rcx, %rdi\n'
#                                '\tjae\t.LBB3_103\n'
#                                '\tleaq\t(%rdi,%r9,4), %rcx\n'
# ...
#                      '\t.cfi_offset %r12, -40\n'
#                      '\t.cfi_offset %r13, -32\n'
#                      '\t.cfi_offset %r14, -24\n'
#                      '\t.cfi_offset %r15, -16\n'
#                      '\tmovq\t%rsi, %rdi\n'
#                      '\tmovabsq\t$.const.add, %rsi\n'
#                      '\tmovabsq\t$PyArg_UnpackTuple, %rbx\n'
#                      '\tleaq\t40(%rsp), %r8\n'
#                      '\tleaq\t32(%rsp), %r9\n'
#                      '\tmovl\t$2, %edx\n'
#                      '\tmovl\t$2, %ecx\n'
#                      '\txorl\t%eax, %eax\n'
#                      '\tcallq\t*%rbx\n'
#                      '\tmovq\t$0, 8(%rsp)\n'
#                      '\ttestl\t%eax, %eax\n'
#                      '\tje\t.LBB1_1\n'
#                      '\tmovabsq\t'
#                      '$_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd, '
#                      '%rax\n'
#                      '\tcmpq\t$0, (%rax)\n'
#                      '\tje\t.LBB1_4\n'
#                      '\tmovq\t40(%rsp), %rdi\n'
#                      '\tmovabsq\t$PyNumber_Float, %r14\n'
#                      '\tcallq\t*%r14\n'
#                      '\tmovq\t%rax, %rbx\n'
#                      '\tmovabsq\t$PyFloat_AsDouble, %r15\n'
#                      '\tmovq\t%rax, %rdi\n'
#                      '\tcallq\t*%r15\n'
#                      '\tvmovsd\t%xmm0, 24(%rsp)\n'
#                      '\tmovabsq\t$Py_DecRef, %r12\n'
#                      '\tmovq\t%rbx, %rdi\n'
#                      '\tcallq\t*%r12\n'
#                      '\tmovabsq\t$PyErr_Occurred, %r13\n'
#                      '\tcallq\t*%r13\n'
#                      '\ttestq\t%rax, %rax\n'
#                      '\tjne\t.LBB1_1\n'
#                      '\tmovq\t32(%rsp), %rdi\n'
#                      '\tcallq\t*%r14\n'
#                      '\tmovq\t%rax, %rbx\n'
#                      '\tmovq\t%rax, %rdi\n'
#                      '\tcallq\t*%r15\n'
#                      '\tvmovsd\t%xmm0, 16(%rsp)\n'
#                      '\tmovq\t%rbx, %rdi\n'
#                      '\tcallq\t*%r12\n'
#                      '\tcallq\t*%r13\n'
#                      '\ttestq\t%rax, %rax\n'
#                      '\tjne\t.LBB1_1\n'
#                      '\tmovq\t$0, 8(%rsp)\n'
#                      '\tmovabsq\t'
#                      '$_ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd, '
#                      '%rax\n'
#                      '\tleaq\t8(%rsp), %rdi\n'
#                      '\tvmovsd\t24(%rsp), %xmm0\n'
#                      '\tvmovsd\t16(%rsp), %xmm1\n'
#                      '\tcallq\t*%rax\n'
#                      '\tvmovsd\t8(%rsp), %xmm0\n'
#                      '\tmovabsq\t$PyFloat_FromDouble, %rax\n'
#                      '\tcallq\t*%rax\n'
#                      '.LBB1_2:\n'
#                      '\taddq\t$48, %rsp\n'
#                      '\t.cfi_def_cfa_offset 48\n'
#                      '\tpopq\t%rbx\n'
#                      '\t.cfi_def_cfa_offset 40\n'
#                      '\tpopq\t%r12\n'
#                      '\t.cfi_def_cfa_offset 32\n'
#                      '\tpopq\t%r13\n'
#                      '\t.cfi_def_cfa_offset 24\n'
#                      '\tpopq\t%r14\n'
#                      '\t.cfi_def_cfa_offset 16\n'
#                      '\tpopq\t%r15\n'
#                      '\t.cfi_def_cfa_offset 8\n'
#                      '\tretq\n'
#                      '.LBB1_4:\n'
#                      '\t.cfi_def_cfa_offset 96\n'
#                      '\tmovabsq\t$PyExc_RuntimeError, %rdi\n'
#                      '\tmovabsq\t$".const.missing Environment: '
#                      '_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd", '
#                      '%rsi\n'
#                      '\tmovabsq\t$PyErr_SetString, %rax\n'
#                      '\tcallq\t*%rax\n'
#                      '.LBB1_1:\n'
#                      '\txorl\t%eax, %eax\n'
#                      '\tjmp\t.LBB1_2\n'
#                      '.Lfunc_end1:\n'
#                      '\t.size\t'
#                      '_ZN7cpython8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd, '
#                      '.Lfunc_end1-_ZN7cpython8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd\n'
#                      '\t.cfi_endproc\n'
#                      '\n'
#                      '\t.globl\t'
#                      'cfunc._ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd\n'
#                      '\t.p2align\t4, 0x90\n'
#                      '\t.type\t'
#                      'cfunc._ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd,@function\n'
#                      'cfunc._ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd:\n'
#                      '\tpushq\t%rax\n'
#                      '\tmovq\t$0, (%rsp)\n'
#                      '\tmovabsq\t'
#                      '$_ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd, '
#                      '%rax\n'
#                      '\tmovq\t%rsp, %rdi\n'
#                      '\tcallq\t*%rax\n'
#                      '\tvmovsd\t(%rsp), %xmm0\n'
#                      '\tpopq\t%rax\n'
#                      '\tretq\n'
#                      '.Lfunc_end2:\n'
#                      '\t.size\t'
#                      'cfunc._ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd, '
#                      '.Lfunc_end2-cfunc._ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd\n'
#                      '\n'
#                      '\t.type\t'
#                      '_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd,@object\n'
#                      '\t.comm\t'
#                      '_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd,8,8\n'
#                      '\t.type\t.const.add,@object\n'
#                      '\t.section\t.rodata,"a",@progbits\n'
#                      '.const.add:\n'
#                      '\t.asciz\t"add"\n'
#                      '\t.size\t.const.add, 4\n'
#                      '\n'
#                      '\t.type\t".const.missing Environment: '
#                      '_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd",@object\n'
#                      '\t.p2align\t4\n'
#                      '".const.missing Environment: '
#                      '_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd":\n'
#                      '\t.asciz\t"missing Environment: '
#                      '_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd"\n'
#                      '\t.size\t".const.missing Environment: '
#                      '_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd", '
#                      '102\n'
#                      '\n'
#                      '\t.section\t".note.GNU-stack","",@progbits\n',
#  (int64, int64): '\t.text\n'
#                  '\t.file\t"<string>"\n'
#                  '\t.globl\t'
#                  '_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\t.p2align\t4, 0x90\n'
#                  '\t.type\t'
#                  '_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,@function\n'
#                  '_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx:\n'
#                  '\taddq\t%rcx, %rdx\n'
#                  '\tmovq\t%rdx, (%rdi)\n'
#                  '\txorl\t%eax, %eax\n'
#                  '\tretq\n'
#                  '.Lfunc_end0:\n'
#                  '\t.size\t'
#                  '_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '.Lfunc_end0-_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\n'
#                  '\t.globl\t'
#                  '_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\t.p2align\t4, 0x90\n'
#                  '\t.type\t'
#                  '_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,@function\n'
#                  '_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx:\n'
#                  '\t.cfi_startproc\n'
#                  '\tpushq\t%rbp\n'
#                  '\t.cfi_def_cfa_offset 16\n'
#                  '\tpushq\t%r15\n'
#                  '\t.cfi_def_cfa_offset 24\n'
#                  '\tpushq\t%r14\n'
#                  '\t.cfi_def_cfa_offset 32\n'
#                  '\tpushq\t%r13\n'
#                  '\t.cfi_def_cfa_offset 40\n'
#                  '\tpushq\t%r12\n'
#                  '\t.cfi_def_cfa_offset 48\n'
#                  '\tpushq\t%rbx\n'
#                  '\t.cfi_def_cfa_offset 56\n'
#                  '\tsubq\t$24, %rsp\n'
#                  '\t.cfi_def_cfa_offset 80\n'
#                  '\t.cfi_offset %rbx, -56\n'
#                  '\t.cfi_offset %r12, -48\n'
#                  '\t.cfi_offset %r13, -40\n'
#                  '\t.cfi_offset %r14, -32\n'
#                  '\t.cfi_offset %r15, -24\n'
#                  '\t.cfi_offset %rbp, -16\n'
#                  '\tmovq\t%rsi, %rdi\n'
#                  '\tmovabsq\t$.const.add, %rsi\n'
#                  '\tmovabsq\t$PyArg_UnpackTuple, %rbp\n'
#                  '\tleaq\t16(%rsp), %r8\n'
#                  '\tleaq\t8(%rsp), %r9\n'
#                  '\tmovl\t$2, %edx\n'
#                  '\tmovl\t$2, %ecx\n'
#                  '\txorl\t%eax, %eax\n'
#                  '\tcallq\t*%rbp\n'
#                  '\tmovq\t$0, (%rsp)\n'
#                  '\ttestl\t%eax, %eax\n'
#                  '\tje\t.LBB1_1\n'
#                  '\tmovabsq\t'
#                  '$_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '%rax\n'
#                  '\tcmpq\t$0, (%rax)\n'
#                  '\tje\t.LBB1_4\n'
#                  '\tmovq\t16(%rsp), %rdi\n'
#                  '\tmovabsq\t$PyNumber_Long, %r13\n'
#                  '\tcallq\t*%r13\n'
#                  '\tmovabsq\t$PyLong_AsLongLong, %r15\n'
#                  '\tmovabsq\t$Py_DecRef, %r12\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tje\t.LBB1_6\n'
#                  '\tmovq\t%rax, %rbx\n'
#                  '\tmovq\t%rax, %rdi\n'
#                  '\tcallq\t*%r15\n'
#                  '\tmovq\t%rax, %r14\n'
#                  '\tmovq\t%rbx, %rdi\n'
#                  '\tcallq\t*%r12\n'
#                  '\tmovabsq\t$PyErr_Occurred, %rbp\n'
#                  '\tcallq\t*%rbp\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tjne\t.LBB1_1\n'
#                  '.LBB1_9:\n'
#                  '\tmovq\t8(%rsp), %rdi\n'
#                  '\tcallq\t*%r13\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tje\t.LBB1_10\n'
#                  '\tmovq\t%rax, %rbx\n'
#                  '\tmovq\t%rax, %rdi\n'
#                  '\tcallq\t*%r15\n'
#                  '\tmovq\t%rax, %r15\n'
#                  '\tmovq\t%rbx, %rdi\n'
#                  '\tcallq\t*%r12\n'
#                  '\tcallq\t*%rbp\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tjne\t.LBB1_1\n'
#                  '.LBB1_13:\n'
#                  '\tmovq\t$0, (%rsp)\n'
#                  '\tmovabsq\t'
#                  '$_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '%rax\n'
#                  '\tmovq\t%rsp, %rdi\n'
#                  '\tmovq\t%r14, %rdx\n'
#                  '\tmovq\t%r15, %rcx\n'
#                  '\tcallq\t*%rax\n'
#                  '\tmovq\t(%rsp), %rdi\n'
#                  '\tmovabsq\t$PyLong_FromLongLong, %rax\n'
#                  '\tcallq\t*%rax\n'
#                  '.LBB1_2:\n'
#                  '\taddq\t$24, %rsp\n'
#                  '\t.cfi_def_cfa_offset 56\n'
#                  '\tpopq\t%rbx\n'
#                  '\t.cfi_def_cfa_offset 48\n'
#                  '\tpopq\t%r12\n'
#                  '\t.cfi_def_cfa_offset 40\n'
#                  '\tpopq\t%r13\n'
#                  '\t.cfi_def_cfa_offset 32\n'
#                  '\tpopq\t%r14\n'
#                  '\t.cfi_def_cfa_offset 24\n'
#                  '\tpopq\t%r15\n'
#                  '\t.cfi_def_cfa_offset 16\n'
#                  '\tpopq\t%rbp\n'
#                  '\t.cfi_def_cfa_offset 8\n'
#                  '\tretq\n'
#                  '.LBB1_4:\n'
#                  '\t.cfi_def_cfa_offset 80\n'
#                  '\tmovabsq\t$PyExc_RuntimeError, %rdi\n'
#                  '\tmovabsq\t$".const.missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx", '
#                  '%rsi\n'
#                  '\tmovabsq\t$PyErr_SetString, %rax\n'
#                  '\tcallq\t*%rax\n'
#                  '.LBB1_1:\n'
#                  '\txorl\t%eax, %eax\n'
#                  '\tjmp\t.LBB1_2\n'
#                  '.LBB1_6:\n'
#                  '\txorl\t%r14d, %r14d\n'
#                  '\tmovabsq\t$PyErr_Occurred, %rbp\n'
#                  '\tcallq\t*%rbp\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tje\t.LBB1_9\n'
#                  '\tjmp\t.LBB1_1\n'
#                  '.LBB1_10:\n'
#                  '\txorl\t%r15d, %r15d\n'
#                  '\tcallq\t*%rbp\n'
#                  '\ttestq\t%rax, %rax\n'
#                  '\tje\t.LBB1_13\n'
#                  '\tjmp\t.LBB1_1\n'
#                  '.Lfunc_end1:\n'
#                  '\t.size\t'
#                  '_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '.Lfunc_end1-_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\t.cfi_endproc\n'
#                  '\n'
#                  '\t.globl\t'
#                  'cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\t.p2align\t4, 0x90\n'
#                  '\t.type\t'
#                  'cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,@function\n'
#                  'cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx:\n'
#                  '\tpushq\t%rax\n'
#                  '\tmovq\t%rsi, %rcx\n'
#                  '\tmovq\t%rdi, %rdx\n'
#                  '\tmovq\t$0, (%rsp)\n'
#                  '\tmovabsq\t'
#                  '$_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '%rax\n'
#                  '\tmovq\t%rsp, %rdi\n'
#                  '\tcallq\t*%rax\n'
#                  '\tmovq\t(%rsp), %rax\n'
#                  '\tpopq\t%rcx\n'
#                  '\tretq\n'
#                  '.Lfunc_end2:\n'
#                  '\t.size\t'
#                  'cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, '
#                  '.Lfunc_end2-cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\n'
#                  '\n'
#                  '\t.type\t'
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,@object\n'
#                  '\t.comm\t'
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx,8,8\n'
#                  '\t.type\t.const.add,@object\n'
#                  '\t.section\t.rodata,"a",@progbits\n'
#                  '.const.add:\n'
#                  '\t.asciz\t"add"\n'
#                  '\t.size\t.const.add, 4\n'
#                  '\n'
#                  '\t.type\t".const.missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx",@object\n'
#                  '\t.p2align\t4\n'
#                  '".const.missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx":\n'
#                  '\t.asciz\t"missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx"\n'
#                  '\t.size\t".const.missing Environment: '
#                  '_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx", '
#                  '102\n'
#                  '\n'
#                  '\t.section\t".note.GNU-stack","",@progbits\n'}

# %% [markdown]
# ### What about the actual LLVM code?
#
# You can see the actual LLVM code generated by Numba using the `inspect_llvm()` method.  Since it's a `dict`, doing the following will be slightly more visually friendly.

# %%
for k, v in add.inspect_llvm().items():
    print(k, v)
# Out:
# (int64, int64) ; ModuleID = 'add'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx = common local_unnamed_addr global i8* null
# @.const.add = internal constant [4 x i8] c"add\00"
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx" = internal constant [102 x i8] c"missing Environment: _ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx\00"
#
# ; Function Attrs: nofree norecurse nounwind writeonly
# define i32 @_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx(i64* noalias nocapture %retptr, { i8*, i32, i8* }** noalias nocapture readnone %excinfo, i64 %arg.a, i64 %arg.b) local_unnamed_addr #0 {
# entry:
#   %.6 = add nsw i64 %arg.b, %arg.a
#   store i64 %.6, i64* %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([4 x i8], [4 x i8]* @.const.add, i64 0, i64 0), i64 2, i64 2, i8** nonnull %.5, i8** nonnull %.6)
#   %.8 = icmp eq i32 %.7, 0
#   %.53 = alloca i64, align 8
#   store i64 0, i64* %.53, align 8
#   br i1 %.8, label %entry.if, label %entry.endif, !prof !0
#
# entry.if:                                         ; preds = %entry.endif.endif.endif.endif.endif, %entry.endif.endif.endif, %entry
#   ret i8* null
#
# entry.endif:                                      ; preds = %entry
#   %.12 = load i8*, i8** @_ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx, align 8
#   %.17 = icmp eq i8* %.12, null
#   br i1 %.17, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([102 x i8], [102 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx", i64 0, i64 0))
#   ret i8* null
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.21 = load i8*, i8** %.5, align 8
#   %.24 = call i8* @PyNumber_Long(i8* %.21)
#   %.25.not = icmp eq i8* %.24, null
#   br i1 %.25.not, label %entry.endif.endif.endif, label %entry.endif.endif.if, !prof !0
#
# entry.endif.endif.if:                             ; preds = %entry.endif.endif
#   %.27 = call i64 @PyLong_AsLongLong(i8* nonnull %.24)
#   call void @Py_DecRef(i8* nonnull %.24)
#   br label %entry.endif.endif.endif
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif, %entry.endif.endif.if
#   %.22.0 = phi i64 [ %.27, %entry.endif.endif.if ], [ 0, %entry.endif.endif ]
#   %.32 = call i8* @PyErr_Occurred()
#   %.33.not = icmp eq i8* %.32, null
#   br i1 %.33.not, label %entry.endif.endif.endif.endif, label %entry.if, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %.37 = load i8*, i8** %.6, align 8
#   %.40 = call i8* @PyNumber_Long(i8* %.37)
#   %.41.not = icmp eq i8* %.40, null
#   br i1 %.41.not, label %entry.endif.endif.endif.endif.endif, label %entry.endif.endif.endif.endif.if, !prof !0
#
# entry.endif.endif.endif.endif.if:                 ; preds = %entry.endif.endif.endif.endif
#   %.43 = call i64 @PyLong_AsLongLong(i8* nonnull %.40)
#   call void @Py_DecRef(i8* nonnull %.40)
#   br label %entry.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif, %entry.endif.endif.endif.endif.if
#   %.38.0 = phi i64 [ %.43, %entry.endif.endif.endif.endif.if ], [ 0, %entry.endif.endif.endif.endif ]
#   %.48 = call i8* @PyErr_Occurred()
#   %.49.not = icmp eq i8* %.48, null
#   br i1 %.49.not, label %entry.endif.endif.endif.endif.endif.endif, label %entry.if, !prof !1
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   store i64 0, i64* %.53, align 8
#   %.57 = call i32 @_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx(i64* nonnull %.53, { i8*, i32, i8* }** undef, i64 %.22.0, i64 %.38.0) #2
#   %.67 = load i64, i64* %.53, align 8
#   %.74 = call i8* @PyLong_FromLongLong(i64 %.67)
#   ret i8* %.74
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Long(i8*) local_unnamed_addr
#
# declare i64 @PyLong_AsLongLong(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyLong_FromLongLong(i64) local_unnamed_addr
#
# ; Function Attrs: nofree norecurse nounwind writeonly
# define i64 @cfunc._ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx(i64 %.1, i64 %.2) local_unnamed_addr #0 {
# entry:
#   %.4 = alloca i64, align 8
#   store i64 0, i64* %.4, align 8
#   %.8 = call i32 @_ZN8__main__3addB2v2B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dExx(i64* nonnull %.4, { i8*, i32, i8* }** undef, i64 %.1, i64 %.2) #2
#   %.18 = load i64, i64* %.4, align 8
#   ret i64 %.18
# }
#
# ; Function Attrs: nounwind
# declare void @llvm.stackprotector(i8*, i8**) #1
#
# attributes #0 = { nofree norecurse nounwind writeonly }
# attributes #1 = { nounwind }
# attributes #2 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}
#
# (float64, float64) ; ModuleID = 'add'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd = common local_unnamed_addr global i8* null
# @.const.add = internal constant [4 x i8] c"add\00"
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd" = internal constant [102 x i8] c"missing Environment: _ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd\00"
#
# ; Function Attrs: nofree norecurse nounwind writeonly
# define i32 @_ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd(double* noalias nocapture %retptr, { i8*, i32, i8* }** noalias nocapture readnone %excinfo, double %arg.a, double %arg.b) local_unnamed_addr #0 {
# entry:
#   %.6 = fadd double %arg.a, %arg.b
#   store double %.6, double* %retptr, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([4 x i8], [4 x i8]* @.const.add, i64 0, i64 0), i64 2, i64 2, i8** nonnull %.5, i8** nonnull %.6)
#   %.8 = icmp eq i32 %.7, 0
#   %.39 = alloca double, align 8
#   store double 0.000000e+00, double* %.39, align 8
#   br i1 %.8, label %entry.if, label %entry.endif, !prof !0
#
# entry.if:                                         ; preds = %entry.endif.endif.endif, %entry.endif.endif, %entry
#   ret i8* null
#
# entry.endif:                                      ; preds = %entry
#   %.12 = load i8*, i8** @_ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd, align 8
#   %.17 = icmp eq i8* %.12, null
#   br i1 %.17, label %entry.endif.if, label %entry.endif.endif, !prof !0
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([102 x i8], [102 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd", i64 0, i64 0))
#   ret i8* null
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.21 = load i8*, i8** %.5, align 8
#   %.22 = call i8* @PyNumber_Float(i8* %.21)
#   %.23 = call double @PyFloat_AsDouble(i8* %.22)
#   call void @Py_DecRef(i8* %.22)
#   %.25 = call i8* @PyErr_Occurred()
#   %.26.not = icmp eq i8* %.25, null
#   br i1 %.26.not, label %entry.endif.endif.endif, label %entry.if, !prof !1
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif
#   %.30 = load i8*, i8** %.6, align 8
#   %.31 = call i8* @PyNumber_Float(i8* %.30)
#   %.32 = call double @PyFloat_AsDouble(i8* %.31)
#   call void @Py_DecRef(i8* %.31)
#   %.34 = call i8* @PyErr_Occurred()
#   %.35.not = icmp eq i8* %.34, null
#   br i1 %.35.not, label %entry.endif.endif.endif.endif, label %entry.if, !prof !1
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   store double 0.000000e+00, double* %.39, align 8
#   %.43 = call i32 @_ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd(double* nonnull %.39, { i8*, i32, i8* }** undef, double %.23, double %.32) #2
#   %.53 = load double, double* %.39, align 8
#   %.58 = call i8* @PyFloat_FromDouble(double %.53)
#   ret i8* %.58
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @PyNumber_Float(i8*) local_unnamed_addr
#
# declare double @PyFloat_AsDouble(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare i8* @PyFloat_FromDouble(double) local_unnamed_addr
#
# ; Function Attrs: nofree norecurse nounwind writeonly
# define double @cfunc._ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd(double %.1, double %.2) local_unnamed_addr #0 {
# entry:
#   %.4 = alloca double, align 8
#   store double 0.000000e+00, double* %.4, align 8
#   %.8 = call i32 @_ZN8__main__3addB2v3B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dEdd(double* nonnull %.4, { i8*, i32, i8* }** undef, double %.1, double %.2) #2
#   %.18 = load double, double* %.4, align 8
#   ret double %.18
# }
#
# ; Function Attrs: nounwind
# declare void @llvm.stackprotector(i8*, i8**) #1
#
# attributes #0 = { nofree norecurse nounwind writeonly }
# attributes #1 = { nounwind }
# attributes #2 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{!"branch_weights", i32 99, i32 1}
#
# (unicode_type, unicode_type) ; ModuleID = 'add'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# @_ZN08NumbaEnv8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type = common local_unnamed_addr global i8* null
# @.const.add = internal constant [4 x i8] c"add\00"
# @PyExc_RuntimeError = external global i8
# @".const.missing Environment: _ZN08NumbaEnv8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type" = internal constant [128 x i8] c"missing Environment: _ZN08NumbaEnv8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type\00"
# @_Py_NoneStruct = external global i8
# @PyExc_StopIteration = external global i8
# @PyExc_SystemError = external global i8
# @".const.unknown error when calling native function" = internal constant [43 x i8] c"unknown error when calling native function\00"
# @".const.<numba.core.cpu.CPUContext object at 0x7e6bdc27a050>" = internal constant [53 x i8] c"<numba.core.cpu.CPUContext object at 0x7e6bdc27a050>\00"
# @".const.unknown error when calling native function.1" = internal constant [43 x i8] c"unknown error when calling native function\00"
# @_ZN08NumbaEnv5numba7cpython7unicode14unicode_concat12_3clocals_3e11concat_implB2v5B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type12unicode_type = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba7cpython7unicode10_pick_kindB2v6B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dEii = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba7cpython7unicode11_pick_asciiB2v7B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dEjj = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba7cpython7unicode13_empty_stringB2v8B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dEixj = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba7cpython7unicode19_kind_to_byte_widthB2v9B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dEi = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba7cpython7unicode15_set_code_pointB3v10B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexj = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba7cpython7unicode11unicode_len12_3clocals_3e8len_implB3v11B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba7cpython7unicode15_get_code_pointB3v12B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typex = common local_unnamed_addr global i8* null
# @_ZN08NumbaEnv5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx = common local_unnamed_addr global i8* null
# @.const.picklebuf.139001721367936 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([86 x i8], [86 x i8]* @.const.pickledata.139001721367936, i32 0, i32 0), i32 86, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.139001721367936.sha1, i32 0, i32 0) }
# @.const.picklebuf.139001720271872 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([176 x i8], [176 x i8]* @.const.pickledata.139001720271872, i32 0, i32 0), i32 176, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.139001720271872.sha1, i32 0, i32 0) }
# @.const.picklebuf.139001720085696 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([191 x i8], [191 x i8]* @.const.pickledata.139001720085696, i32 0, i32 0), i32 191, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.139001720085696.sha1, i32 0, i32 0) }
# @.const.picklebuf.139001719828224 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([182 x i8], [182 x i8]* @.const.pickledata.139001719828224, i32 0, i32 0), i32 182, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.139001719828224.sha1, i32 0, i32 0) }
# @.const.picklebuf.139001721366080 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([167 x i8], [167 x i8]* @.const.pickledata.139001721366080, i32 0, i32 0), i32 167, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.139001721366080.sha1, i32 0, i32 0) }
# @.const.picklebuf.139001720148864 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([181 x i8], [181 x i8]* @.const.pickledata.139001720148864, i32 0, i32 0), i32 181, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.139001720148864.sha1, i32 0, i32 0) }
# @.const.picklebuf.139001720149504 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([191 x i8], [191 x i8]* @.const.pickledata.139001720149504, i32 0, i32 0), i32 191, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.139001720149504.sha1, i32 0, i32 0) }
# @.const.pickledata.139001720149504 = internal constant [191 x i8] c"\80\04\95\B4\00\00\00\00\00\00\00\8C\08builtins\94\8C\0EAssertionError\94\93\94\8C4Unexpected unicode representation in _set_code_point\94\85\94\8C\0F_set_code_point\94\8C@/usr/local/lib/python3.10/dist-packages/numba/cpython/unicode.py\94MX\01\87\94\87\94."
# @.const.pickledata.139001720149504.sha1 = internal constant [20 x i8] c"\9Cq\C3N\F6\A6\AFE\C9\86\8E\0B\19s-\AC\B1^\B2\81"
# @.const.pickledata.139001720148864 = internal constant [181 x i8] c"\80\04\95\AA\00\00\00\00\00\00\00\8C\08builtins\94\8C\0EAssertionError\94\93\94\8C/Unexpected unicode representation in _pick_kind\94\85\94\8C\0A_pick_kind\94\8C@/usr/local/lib/python3.10/dist-packages/numba/cpython/unicode.py\94Mk\01\87\94\87\94."
# @.const.pickledata.139001720148864.sha1 = internal constant [20 x i8] c"t\05\BE\BA]\C3\DB\E2\B8\CB\91\B6=\FB\F8\A0\DE\C2\D1\C2"
# @.const.pickledata.139001721366080 = internal constant [167 x i8] c"\80\04\95\9C\00\00\00\00\00\00\00\8C\08builtins\94\8C\0EAssertionError\94\93\94\8C!PY_UNICODE_WCHAR_KIND unsupported\94\85\94\8C\0A_pick_kind\94\8C@/usr/local/lib/python3.10/dist-packages/numba/cpython/unicode.py\94M_\01\87\94\87\94."
# @.const.pickledata.139001721366080.sha1 = internal constant [20 x i8] c"7J\\\85\99\95mn\83\02?,\11\E7I\EFu\C6\8A\DB"
# @.const.pickledata.139001719828224 = internal constant [182 x i8] c"\80\04\95\AB\00\00\00\00\00\00\00\8C\08builtins\94\8C\0EAssertionError\94\93\94\8C'Unexpected unicode encoding encountered\94\85\94\8C\13_kind_to_byte_width\94\8C@/usr/local/lib/python3.10/dist-packages/numba/cpython/unicode.py\94M\80\01\87\94\87\94."
# @.const.pickledata.139001719828224.sha1 = internal constant [20 x i8] c"\C1\06,zasg\10\C2;O\81?\EA\FE\05\1E\C6\05\B6"
# @.const.pickledata.139001720085696 = internal constant [191 x i8] c"\80\04\95\B4\00\00\00\00\00\00\00\8C\08builtins\94\8C\0EAssertionError\94\93\94\8C4Unexpected unicode representation in _set_code_point\94\85\94\8C\0F_set_code_point\94\8C@/usr/local/lib/python3.10/dist-packages/numba/cpython/unicode.py\94MX\01\87\94\87\94."
# @.const.pickledata.139001720085696.sha1 = internal constant [20 x i8] c"\9Cq\C3N\F6\A6\AFE\C9\86\8E\0B\19s-\AC\B1^\B2\81"
# @.const.pickledata.139001720271872 = internal constant [176 x i8] c"\80\04\95\A5\00\00\00\00\00\00\00\8C\08builtins\94\8C\0EAssertionError\94\93\94\8C!PY_UNICODE_WCHAR_KIND unsupported\94\85\94\8C\13_kind_to_byte_width\94\8C@/usr/local/lib/python3.10/dist-packages/numba/cpython/unicode.py\94M~\01\87\94\87\94."
# @.const.pickledata.139001720271872.sha1 = internal constant [20 x i8] c"\13\F1\7Fp\8D5\8E\9DiG\F9*\FCpN&j\04\EBg"
# @.const.pickledata.139001721367936 = internal constant [86 x i8] c"\80\04\95K\00\00\00\00\00\00\00\8C\08builtins\94\8C\0BMemoryError\94\93\94\8C'Allocation failed (probably too large).\94\85\94N\87\94."
# @.const.pickledata.139001721367936.sha1 = internal constant [20 x i8] c"\BA(\9D\81\F0\\p \F3G|\15sH\04\DFe\AB\E2\09"
#
# define i32 @_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type({ i8*, i64, i32, i32, i64, i8*, i8* }* noalias nocapture %retptr, { i8*, i32, i8* }** noalias nocapture %excinfo, i8* nocapture readonly %arg.a.0, i64 %arg.a.1, i32 %arg.a.2, i32 %arg.a.3, i64 %arg.a.4, i8* %arg.a.5, i8* nocapture readnone %arg.a.6, i8* nocapture readonly %arg.b.0, i64 %arg.b.1, i32 %arg.b.2, i32 %arg.b.3, i64 %arg.b.4, i8* %arg.b.5, i8* nocapture readnone %arg.b.6) local_unnamed_addr {
# entry:
#   %.20 = alloca { i8*, i64, i32, i32, i64, i8*, i8* }, align 16
#   %excinfo.1 = alloca { i8*, i32, i8* }*, align 8
#   store { i8*, i32, i8* }* null, { i8*, i32, i8* }** %excinfo.1, align 8
#   %0 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.20 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 16 dereferenceable(48) %0, i8 0, i64 48, i1 false)
#   %.24 = call i32 @_ZN5numba7cpython7unicode14unicode_concat12_3clocals_3e11concat_implB2v5B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type12unicode_type({ i8*, i64, i32, i32, i64, i8*, i8* }* nonnull %.20, { i8*, i32, i8* }** nonnull %excinfo.1, i8* %arg.a.0, i64 %arg.a.1, i32 %arg.a.2, i32 %arg.a.3, i64 %arg.a.4, i8* %arg.a.5, i8* %arg.a.6, i8* %arg.b.0, i64 %arg.b.1, i32 %arg.b.2, i32 %arg.b.3, i64 %arg.b.4, i8* %arg.b.5, i8* %arg.b.6)
#   switch i32 %.24, label %B0.if [
#     i32 -2, label %B0.endif
#     i32 0, label %B0.endif
#   ]
#
# B0.if:                                            ; preds = %entry
#   %1 = bitcast { i8*, i32, i8* }** %excinfo.1 to i64*
#   %.251 = load i64, i64* %1, align 8
#   %2 = bitcast { i8*, i32, i8* }** %excinfo to i64*
#   store i64 %.251, i64* %2, align 8
#   ret i32 %.24, !ret_is_raise !6
#
# B0.endif:                                         ; preds = %entry, %entry
#   %.fca.6.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.20, i64 0, i32 6
#   %.fca.4.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.20, i64 0, i32 4
#   %.fca.3.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.20, i64 0, i32 3
#   %.fca.2.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.20, i64 0, i32 2
#   %3 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.20 to <2 x i64>*
#   %4 = load <2 x i64>, <2 x i64>* %3, align 16
#   %.34.fca.2.load = load i32, i32* %.fca.2.gep, align 16
#   %.34.fca.3.load = load i32, i32* %.fca.3.gep, align 4
#   %5 = bitcast i64* %.fca.4.gep to <2 x i64>*
#   %6 = load <2 x i64>, <2 x i64>* %5, align 8
#   %7 = bitcast i8** %.fca.6.gep to i64*
#   %.34.fca.6.load16 = load i64, i64* %7, align 8
#   %8 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr to <2 x i64>*
#   store <2 x i64> %4, <2 x i64>* %8, align 8
#   %retptr.repack4 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 2
#   store i32 %.34.fca.2.load, i32* %retptr.repack4, align 8
#   %retptr.repack6 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 3
#   store i32 %.34.fca.3.load, i32* %retptr.repack6, align 4
#   %retptr.repack8 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 4
#   %9 = bitcast i64* %retptr.repack8 to <2 x i64>*
#   store <2 x i64> %6, <2 x i64>* %9, align 8
#   %retptr.repack12 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 6
#   %10 = bitcast i8** %retptr.repack12 to i64*
#   store i64 %.34.fca.6.load16, i64* %10, align 8
#   ret i32 0
# }
#
# define i8* @_ZN7cpython8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type(i8* nocapture readnone %py_closure, i8* %py_args, i8* nocapture readnone %py_kws) local_unnamed_addr {
# entry:
#   %.5 = alloca i8*, align 8
#   %.6 = alloca i8*, align 8
#   %.7 = call i32 (i8*, i8*, i64, i64, ...) @PyArg_UnpackTuple(i8* %py_args, i8* getelementptr inbounds ([4 x i8], [4 x i8]* @.const.add, i64 0, i64 0), i64 2, i64 2, i8** nonnull %.5, i8** nonnull %.6)
#   %.8 = icmp eq i32 %.7, 0
#   %.22 = alloca i64, align 8
#   store i64 0, i64* %.22, align 8
#   %.24 = alloca i32, align 4
#   store i32 0, i32* %.24, align 4
#   %.26 = alloca i32, align 4
#   store i32 0, i32* %.26, align 4
#   %.28 = alloca i64, align 8
#   store i64 0, i64* %.28, align 8
#   %.62 = alloca i64, align 8
#   store i64 0, i64* %.62, align 8
#   %.64 = alloca i32, align 4
#   store i32 0, i32* %.64, align 4
#   %.66 = alloca i32, align 4
#   store i32 0, i32* %.66, align 4
#   %.68 = alloca i64, align 8
#   store i64 0, i64* %.68, align 8
#   %.101 = alloca { i8*, i64, i32, i32, i64, i8*, i8* }, align 8
#   %excinfo = alloca { i8*, i32, i8* }*, align 8
#   %0 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.101 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 dereferenceable(48) %0, i8 0, i64 48, i1 false)
#   store { i8*, i32, i8* }* null, { i8*, i32, i8* }** %excinfo, align 8
#   br i1 %.8, label %entry.if, label %entry.endif, !prof !7
#
# entry.if:                                         ; preds = %entry.endif.endif.endif.endif.endif.if, %entry.endif.endif, %entry.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.endif.endif.if.if, %entry.endif.endif.endif.endif.endif.endif.if, %entry.endif.endif.endif.endif.endif.endif.endif.endif, %entry.endif.endif.endif.if, %entry
#   ret i8* null
#
# entry.endif:                                      ; preds = %entry
#   %.12 = load i8*, i8** @_ZN08NumbaEnv8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type, align 8
#   %.17 = icmp eq i8* %.12, null
#   br i1 %.17, label %entry.endif.if, label %entry.endif.endif, !prof !7
#
# entry.endif.if:                                   ; preds = %entry.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_RuntimeError, i8* getelementptr inbounds ([128 x i8], [128 x i8]* @".const.missing Environment: _ZN08NumbaEnv8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type", i64 0, i64 0))
#   ret i8* null
#
# entry.endif.endif:                                ; preds = %entry.endif
#   %.21 = load i8*, i8** %.5, align 8
#   %.30 = call i8* @numba_extract_unicode(i8* %.21, i64* nonnull %.22, i32* nonnull %.24, i32* nonnull %.26, i64* nonnull %.28)
#   %.32 = load i64, i64* %.22, align 8
#   %.33 = load i32, i32* %.24, align 4
#   %.34 = load i32, i32* %.26, align 4
#   %.35 = load i64, i64* %.28, align 8
#   %.49 = call i8* @NRT_meminfo_new_from_pyobject(i8* %.30, i8* %.21)
#   %.54 = call i8* @PyErr_Occurred()
#   %.55.not = icmp eq i8* %.54, null
#   br i1 %.55.not, label %entry.endif.endif.endif, label %entry.if, !prof !8
#
# entry.endif.endif.endif:                          ; preds = %entry.endif.endif
#   %.61 = load i8*, i8** %.6, align 8
#   %.70 = call i8* @numba_extract_unicode(i8* %.61, i64* nonnull %.62, i32* nonnull %.64, i32* nonnull %.66, i64* nonnull %.68)
#   %.72 = load i64, i64* %.62, align 8
#   %.73 = load i32, i32* %.64, align 4
#   %.74 = load i32, i32* %.66, align 4
#   %.75 = load i64, i64* %.68, align 8
#   %.89 = call i8* @NRT_meminfo_new_from_pyobject(i8* %.70, i8* %.61)
#   %.94 = call i8* @PyErr_Occurred()
#   %.95.not = icmp eq i8* %.94, null
#   br i1 %.95.not, label %entry.endif.endif.endif.endif, label %entry.endif.endif.endif.if, !prof !8
#
# entry.endif.endif.endif.if:                       ; preds = %entry.endif.endif.endif
#   call void @NRT_decref(i8* %.49)
#   br label %entry.if
#
# entry.endif.endif.endif.endif:                    ; preds = %entry.endif.endif.endif
#   %1 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.101 to i8**
#   %2 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.101 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 dereferenceable(48) %2, i8 0, i64 48, i1 false)
#   %.105 = call i32 @_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type({ i8*, i64, i32, i32, i64, i8*, i8* }* nonnull %.101, { i8*, i32, i8* }** nonnull %excinfo, i8* %.30, i64 %.32, i32 %.33, i32 %.34, i64 %.35, i8* %.49, i8* %.21, i8* %.70, i64 %.72, i32 %.73, i32 %.74, i64 %.75, i8* %.89, i8* %.61) #1
#   %.106 = load { i8*, i32, i8* }*, { i8*, i32, i8* }** %excinfo, align 8
#   %.115.fca.0.load = load i8*, i8** %1, align 8
#   %3 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.101 to i8*
#   %sunkaddr = getelementptr inbounds i8, i8* %3, i64 8
#   %4 = bitcast i8* %sunkaddr to i64*
#   %.115.fca.1.load = load i64, i64* %4, align 8
#   %5 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.101 to i8*
#   %sunkaddr2 = getelementptr inbounds i8, i8* %5, i64 16
#   %6 = bitcast i8* %sunkaddr2 to i32*
#   %.115.fca.2.load = load i32, i32* %6, align 8
#   %7 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.101 to i8*
#   %sunkaddr3 = getelementptr inbounds i8, i8* %7, i64 32
#   %8 = bitcast i8* %sunkaddr3 to i8**
#   %.115.fca.5.load = load i8*, i8** %8, align 8
#   call void @NRT_decref(i8* %.49)
#   call void @NRT_decref(i8* %.89)
#   switch i32 %.105, label %entry.endif.endif.endif.endif.endif [
#     i32 -2, label %entry.endif.endif.endif.endif.if.if
#     i32 0, label %entry.endif.endif.endif.endif.if.endif
#   ]
#
# entry.endif.endif.endif.endif.endif:              ; preds = %entry.endif.endif.endif.endif
#   %.113 = icmp sgt i32 %.105, 0
#   br i1 %.113, label %entry.endif.endif.endif.endif.endif.if, label %entry.endif.endif.endif.endif.endif.endif
#
# entry.endif.endif.endif.endif.if.if:              ; preds = %entry.endif.endif.endif.endif
#   call void @Py_IncRef(i8* nonnull @_Py_NoneStruct)
#   ret i8* @_Py_NoneStruct
#
# entry.endif.endif.endif.endif.if.endif:           ; preds = %entry.endif.endif.endif.endif
#   %.139 = call i8* @PyUnicode_FromKindAndData(i32 %.115.fca.2.load, i8* %.115.fca.0.load, i64 %.115.fca.1.load)
#   %.140 = call i64 @PyObject_Hash(i8* %.139)
#   call void @NRT_decref(i8* %.115.fca.5.load)
#   ret i8* %.139
#
# entry.endif.endif.endif.endif.endif.if:           ; preds = %entry.endif.endif.endif.endif.endif
#   call void @PyErr_Clear()
#   %.146 = load { i8*, i32, i8* }, { i8*, i32, i8* }* %.106, align 8
#   %.147 = extractvalue { i8*, i32, i8* } %.146, 0
#   %.149 = extractvalue { i8*, i32, i8* } %.146, 1
#   %.151 = extractvalue { i8*, i32, i8* } %.146, 2
#   %.152 = call i8* @numba_unpickle(i8* %.147, i32 %.149, i8* %.151)
#   %.153.not = icmp eq i8* %.152, null
#   br i1 %.153.not, label %entry.if, label %entry.endif.endif.endif.endif.endif.if.if, !prof !7
#
# entry.endif.endif.endif.endif.endif.endif:        ; preds = %entry.endif.endif.endif.endif.endif
#   switch i32 %.105, label %entry.endif.endif.endif.endif.endif.endif.endif.endif [
#     i32 -3, label %entry.endif.endif.endif.endif.endif.endif.if
#     i32 -1, label %entry.if
#   ]
#
# entry.endif.endif.endif.endif.endif.if.if:        ; preds = %entry.endif.endif.endif.endif.endif.if
#   call void @numba_do_raise(i8* nonnull %.152)
#   br label %entry.if
#
# entry.endif.endif.endif.endif.endif.endif.if:     ; preds = %entry.endif.endif.endif.endif.endif.endif
#   call void @PyErr_SetNone(i8* nonnull @PyExc_StopIteration)
#   br label %entry.if
#
# entry.endif.endif.endif.endif.endif.endif.endif.endif: ; preds = %entry.endif.endif.endif.endif.endif.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_SystemError, i8* getelementptr inbounds ([43 x i8], [43 x i8]* @".const.unknown error when calling native function", i64 0, i64 0))
#   br label %entry.if
# }
#
# declare i32 @PyArg_UnpackTuple(i8*, i8*, i64, i64, ...) local_unnamed_addr
#
# declare void @PyErr_SetString(i8*, i8*) local_unnamed_addr
#
# declare i8* @numba_extract_unicode(i8*, i64*, i32*, i32*, i64*) local_unnamed_addr
#
# declare noalias i8* @NRT_meminfo_new_from_pyobject(i8* nocapture, i8* nocapture) local_unnamed_addr
#
# declare i8* @PyErr_Occurred() local_unnamed_addr
#
# declare void @Py_IncRef(i8*) local_unnamed_addr
#
# declare i8* @PyUnicode_FromKindAndData(i32, i8*, i64) local_unnamed_addr
#
# declare i64 @PyObject_Hash(i8*) local_unnamed_addr
#
# declare void @PyErr_Clear() local_unnamed_addr
#
# declare i8* @numba_unpickle(i8*, i32, i8*) local_unnamed_addr
#
# declare void @numba_do_raise(i8*) local_unnamed_addr
#
# declare void @PyErr_SetNone(i8*) local_unnamed_addr
#
# define { i8*, i64, i32, i32, i64, i8*, i8* } @cfunc._ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type({ i8*, i64, i32, i32, i64, i8*, i8* } %.1, { i8*, i64, i32, i32, i64, i8*, i8* } %.2) local_unnamed_addr {
# entry:
#   %.4 = alloca { i8*, i64, i32, i32, i64, i8*, i8* }, align 8
#   %.fca.0.gep1 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.4 to i8**
#   %.fca.1.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.4, i64 0, i32 1
#   %.fca.2.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.4, i64 0, i32 2
#   %.fca.3.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.4, i64 0, i32 3
#   %.fca.4.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.4, i64 0, i32 4
#   %.fca.5.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.4, i64 0, i32 5
#   %.fca.6.gep = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %.4, i64 0, i32 6
#   %excinfo = alloca { i8*, i32, i8* }*, align 8
#   %0 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %.4 to i8*
#   call void @llvm.memset.p0i8.i64(i8* nonnull align 8 dereferenceable(48) %0, i8 0, i64 48, i1 false)
#   store { i8*, i32, i8* }* null, { i8*, i32, i8* }** %excinfo, align 8
#   %extracted.data = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.1, 0
#   %extracted.length = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.1, 1
#   %extracted.kind = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.1, 2
#   %extracted.is_ascii = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.1, 3
#   %extracted.hash = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.1, 4
#   %extracted.meminfo = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.1, 5
#   %extracted.parent = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.1, 6
#   %extracted.data.1 = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.2, 0
#   %extracted.length.1 = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.2, 1
#   %extracted.kind.1 = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.2, 2
#   %extracted.is_ascii.1 = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.2, 3
#   %extracted.hash.1 = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.2, 4
#   %extracted.meminfo.1 = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.2, 5
#   %extracted.parent.1 = extractvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.2, 6
#   %.8 = call i32 @_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type({ i8*, i64, i32, i32, i64, i8*, i8* }* nonnull %.4, { i8*, i32, i8* }** nonnull %excinfo, i8* %extracted.data, i64 %extracted.length, i32 %extracted.kind, i32 %extracted.is_ascii, i64 %extracted.hash, i8* %extracted.meminfo, i8* %extracted.parent, i8* %extracted.data.1, i64 %extracted.length.1, i32 %extracted.kind.1, i32 %extracted.is_ascii.1, i64 %extracted.hash.1, i8* %extracted.meminfo.1, i8* %extracted.parent.1) #1
#   %.9 = load { i8*, i32, i8* }*, { i8*, i32, i8* }** %excinfo, align 8
#   %.18.fca.0.load = load i8*, i8** %.fca.0.gep1, align 8
#   %.18.fca.1.load = load i64, i64* %.fca.1.gep, align 8
#   %.18.fca.2.load = load i32, i32* %.fca.2.gep, align 8
#   %.18.fca.3.load = load i32, i32* %.fca.3.gep, align 4
#   %.18.fca.4.load = load i64, i64* %.fca.4.gep, align 8
#   %.18.fca.5.load = load i8*, i8** %.fca.5.gep, align 8
#   %.18.fca.6.load = load i8*, i8** %.fca.6.gep, align 8
#   %.27 = alloca i32, align 4
#   store i32 0, i32* %.27, align 4
#   switch i32 %.8, label %entry.if [
#     i32 -2, label %entry.endif
#     i32 0, label %entry.endif
#   ]
#
# entry.if:                                         ; preds = %entry
#   %.16 = icmp sgt i32 %.8, 0
#   call void @numba_gil_ensure(i32* nonnull %.27)
#   br i1 %.16, label %entry.if.if, label %entry.if.endif
#
# entry.endif:                                      ; preds = %entry, %entry, %.30
#   %.18.fca.0.insert = insertvalue { i8*, i64, i32, i32, i64, i8*, i8* } undef, i8* %.18.fca.0.load, 0
#   %.18.fca.1.insert = insertvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.18.fca.0.insert, i64 %.18.fca.1.load, 1
#   %.18.fca.2.insert = insertvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.18.fca.1.insert, i32 %.18.fca.2.load, 2
#   %.18.fca.3.insert = insertvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.18.fca.2.insert, i32 %.18.fca.3.load, 3
#   %.18.fca.4.insert = insertvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.18.fca.3.insert, i64 %.18.fca.4.load, 4
#   %.18.fca.5.insert = insertvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.18.fca.4.insert, i8* %.18.fca.5.load, 5
#   %.18.fca.6.insert = insertvalue { i8*, i64, i32, i32, i64, i8*, i8* } %.18.fca.5.insert, i8* %.18.fca.6.load, 6
#   ret { i8*, i64, i32, i32, i64, i8*, i8* } %.18.fca.6.insert
#
# .30:                                              ; preds = %entry.if.if, %entry.if.endif, %entry.if.if.if, %entry.if.endif.endif.endif, %entry.if.endif.if
#   %.52 = call i8* @PyUnicode_FromString(i8* getelementptr inbounds ([53 x i8], [53 x i8]* @".const.<numba.core.cpu.CPUContext object at 0x7e6bdc27a050>", i64 0, i64 0))
#   call void @PyErr_WriteUnraisable(i8* %.52)
#   call void @Py_DecRef(i8* %.52)
#   call void @numba_gil_release(i32* nonnull %.27)
#   br label %entry.endif
#
# entry.if.if:                                      ; preds = %entry.if
#   call void @PyErr_Clear()
#   %.33 = load { i8*, i32, i8* }, { i8*, i32, i8* }* %.9, align 8
#   %.34 = extractvalue { i8*, i32, i8* } %.33, 0
#   %.36 = extractvalue { i8*, i32, i8* } %.33, 1
#   %.38 = extractvalue { i8*, i32, i8* } %.33, 2
#   %.39 = call i8* @numba_unpickle(i8* %.34, i32 %.36, i8* %.38)
#   %.40.not = icmp eq i8* %.39, null
#   br i1 %.40.not, label %.30, label %entry.if.if.if, !prof !7
#
# entry.if.endif:                                   ; preds = %entry.if
#   switch i32 %.8, label %entry.if.endif.endif.endif [
#     i32 -3, label %entry.if.endif.if
#     i32 -1, label %.30
#   ]
#
# entry.if.if.if:                                   ; preds = %entry.if.if
#   call void @numba_do_raise(i8* nonnull %.39)
#   br label %.30
#
# entry.if.endif.if:                                ; preds = %entry.if.endif
#   call void @PyErr_SetNone(i8* nonnull @PyExc_StopIteration)
#   br label %.30
#
# entry.if.endif.endif.endif:                       ; preds = %entry.if.endif
#   call void @PyErr_SetString(i8* nonnull @PyExc_SystemError, i8* getelementptr inbounds ([43 x i8], [43 x i8]* @".const.unknown error when calling native function.1", i64 0, i64 0))
#   br label %.30
# }
#
# declare void @numba_gil_ensure(i32*) local_unnamed_addr
#
# declare i8* @PyUnicode_FromString(i8*) local_unnamed_addr
#
# declare void @PyErr_WriteUnraisable(i8*) local_unnamed_addr
#
# declare void @Py_DecRef(i8*) local_unnamed_addr
#
# declare void @numba_gil_release(i32*) local_unnamed_addr
#
# define linkonce_odr i32 @_ZN5numba7cpython7unicode14unicode_concat12_3clocals_3e11concat_implB2v5B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type12unicode_type({ i8*, i64, i32, i32, i64, i8*, i8* }* noalias nocapture %retptr, { i8*, i32, i8* }** noalias nocapture %excinfo, i8* nocapture readonly %arg.a.0, i64 %arg.a.1, i32 %arg.a.2, i32 %arg.a.3, i64 %arg.a.4, i8* %arg.a.5, i8* nocapture readnone %arg.a.6, i8* nocapture readonly %arg.b.0, i64 %arg.b.1, i32 %arg.b.2, i32 %arg.b.3, i64 %arg.b.4, i8* %arg.b.5, i8* nocapture readnone %arg.b.6) local_unnamed_addr {
# entry:
#   tail call void @NRT_incref(i8* %arg.a.5)
#   tail call void @NRT_incref(i8* %arg.b.5)
#   %.38 = add nsw i64 %arg.b.1, %arg.a.1
#   %.12.i = icmp eq i32 %arg.a.2, 0
#   %.16.i = icmp eq i32 %arg.b.2, 0
#   %or.cond.i = or i1 %.12.i, %.16.i
#   br i1 %or.cond.i, label %B0.if.if, label %B26.i, !prof !9
#
# B26.i:                                            ; preds = %entry
#   %.11.i = sext i32 %arg.a.2 to i64
#   switch i64 %.11.i, label %B0.if.if [
#     i64 1, label %B0.endif
#     i64 2, label %B46.i
#     i64 4, label %B70.i
#   ]
#
# B46.i:                                            ; preds = %B26.i
#   %.46.i = icmp eq i32 %arg.b.2, 4
#   %.arg.a.2 = select i1 %.46.i, i32 4, i32 %arg.a.2
#   br label %B0.endif
#
# B70.i:                                            ; preds = %B26.i
#   br label %B0.endif
#
# B68:                                              ; preds = %B68.preheader562, %_ZN5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx.exit21
#   %.200.0116 = phi i64 [ %.269, %_ZN5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx.exit21 ], [ 0, %B68.preheader562 ]
#   %.269 = add nuw nsw i64 %.200.0116, 1
#   switch i64 %.8.i.i, label %B0.if.if.loopexit563 [
#     i64 4, label %B68.i19
#     i64 2, label %B40.i15
#   ]
#
# B134:                                             ; preds = %B104.endif.us149.us98, %B104.endif.us149.us, %B68.i.us162, %B104.endif.us118.us78, %B104.endif.us118.us, %B68.i.us134, %B104.endif.us.us61, %B104.endif.us.us58, %B104.endif.us.us, %B104.endif.us149.us98.prol.loopexit, %B104.endif.us149.us.prol.loopexit, %B104.endif.us118.us78.prol.loopexit, %B104.endif.us118.us.prol.loopexit, %B104.endif.us.us61.prol.loopexit, %B104.endif.us.us58.prol.loopexit, %middle.block300, %middle.block323, %middle.block346, %middle.block369, %middle.block399, %middle.block426, %B104.endif.us43.preheader, %B104.endif.us29.preheader, %B104.endif.us23.preheader, %B104.endif.us.us.prol.loopexit, %middle.block272, %B90.endif
#   %0 = ptrtoint i8* %.38.i to i64
#   %.9.i = icmp eq i32 %arg.a.3, 1
#   %.13.i = icmp eq i32 %arg.b.3, 1
#   %or.cond.i44 = and i1 %.9.i, %.13.i
#   %. = zext i1 %or.cond.i44 to i32
#   %retptr.repack7061848 = bitcast { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr to i8**
#   store i8* %.6.i.i, i8** %retptr.repack7061848, align 8
#   %retptr.repack60 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 1
#   store i64 %.38, i64* %retptr.repack60, align 8
#   %retptr.repack62 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 2
#   store i32 %.53.0.ph, i32* %retptr.repack62, align 8
#   %retptr.repack64 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 3
#   store i32 %., i32* %retptr.repack64, align 4
#   %retptr.repack66 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 4
#   store i64 -1, i64* %retptr.repack66, align 8
#   %retptr.repack68 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 5
#   %1 = bitcast i8** %retptr.repack68 to i64*
#   store i64 %0, i64* %1, align 8
#   %retptr.repack70 = getelementptr inbounds { i8*, i64, i32, i32, i64, i8*, i8* }, { i8*, i64, i32, i32, i64, i8*, i8* }* %retptr, i64 0, i32 6
#   %2 = bitcast i8** %retptr.repack70 to i64*
#   store i64 0, i64* %2, align 8
#   tail call void @NRT_decref(i8* %arg.b.5)
#   tail call void @NRT_decref(i8* %arg.a.5)
#   ret i32 0
#
# B0.endif:                                         ; preds = %B70.i, %B46.i, %B26.i
#   %.53.0.ph = phi i32 [ %.arg.a.2, %B46.i ], [ %arg.b.2, %B26.i ], [ %arg.a.2, %B70.i ]
#   %.8.i.i = sext i32 %.53.0.ph to i64
#   switch i64 %.8.i.i, label %B54.i.i [
#     i64 1, label %B0.endif.i
#     i64 2, label %B0.endif.i
#     i64 4, label %B0.endif.i
#     i64 0, label %B0.if.if
#   ]
#
# B0.if.if.loopexit561:                             ; preds = %B68.us117
#   br label %B0.if.if
#
# B0.if.if.loopexit563:                             ; preds = %B68
#   br label %B0.if.if
#
# B0.if.if.loopexit573:                             ; preds = %B68.us182
#   br label %B0.if.if
#
# B0.if.if:                                         ; preds = %B104.endif.us149, %B104.endif.us118, %B0.if.if.loopexit573, %B0.if.if.loopexit563, %B0.if.if.loopexit561, %B104.endif.preheader, %B104.endif.us.preheader, %B68.us.preheader, %B0.endif.endif.i, %B0.endif.i, %B54.i.i, %B0.endif, %B26.i, %entry
#   %excinfo.1.0.sink = phi { i8*, i32, i8* }* [ @.const.picklebuf.139001721367936, %B0.endif.i ], [ @.const.picklebuf.139001720271872, %B0.endif ], [ @.const.picklebuf.139001720085696, %B0.endif.endif.i ], [ @.const.picklebuf.139001719828224, %B54.i.i ], [ @.const.picklebuf.139001721366080, %entry ], [ @.const.picklebuf.139001720148864, %B26.i ], [ @.const.picklebuf.139001720149504, %B68.us.preheader ], [ @.const.picklebuf.139001720149504, %B104.endif.us.preheader ], [ @.const.picklebuf.139001720149504, %B104.endif.preheader ], [ @.const.picklebuf.139001720149504, %B0.if.if.loopexit561 ], [ @.const.picklebuf.139001720149504, %B0.if.if.loopexit563 ], [ @.const.picklebuf.139001720149504, %B0.if.if.loopexit573 ], [ @.const.picklebuf.139001720149504, %B104.endif.us118 ], [ @.const.picklebuf.139001720149504, %B104.endif.us149 ]
#   store { i8*, i32, i8* }* %excinfo.1.0.sink, { i8*, i32, i8* }** %excinfo, align 8
#   ret i32 1, !ret_is_raise !6
#
# B54.i.i:                                          ; preds = %B0.endif
#   br label %B0.if.if
#
# B0.endif.i:                                       ; preds = %B0.endif, %B0.endif, %B0.endif
#   %.36.i23 = add i64 %.38, 1
#   %.37.i24 = mul i64 %.36.i23, %.8.i.i
#   %.38.i = tail call i8* @NRT_MemInfo_alloc_safe(i64 %.37.i24), !noalias !10
#   %.39.i = icmp eq i8* %.38.i, null
#   br i1 %.39.i, label %B0.if.if, label %B0.endif.endif.i, !prof !7
#
# B0.endif.endif.i:                                 ; preds = %B0.endif.i
#   %.5.i.i = getelementptr i8, i8* %.38.i, i64 24
#   %3 = bitcast i8* %.5.i.i to i8**
#   %.6.i.i = load i8*, i8** %3, align 8, !noalias !10
#   switch i64 %.8.i.i, label %B0.if.if [
#     i64 1, label %B12.i.i
#     i64 2, label %B40.i.i
#     i64 4, label %B68.i.i
#   ]
#
# B12.i.i:                                          ; preds = %B0.endif.endif.i
#   %.41.i.i = getelementptr i8, i8* %.6.i.i, i64 %.38
#   store i8 0, i8* %.41.i.i, align 1, !noalias !14
#   br label %B0.endif.endif.endif.endif
#
# B40.i.i:                                          ; preds = %B0.endif.endif.i
#   %.71.i.i = bitcast i8* %.6.i.i to i16*
#   %.72.i.i = getelementptr i16, i16* %.71.i.i, i64 %.38
#   store i16 0, i16* %.72.i.i, align 2, !noalias !14
#   br label %B0.endif.endif.endif.endif
#
# B68.i.i:                                          ; preds = %B0.endif.endif.i
#   %.101.i.i = bitcast i8* %.6.i.i to i32*
#   %.102.i.i = getelementptr i32, i32* %.101.i.i, i64 %.38
#   store i32 0, i32* %.102.i.i, align 4, !noalias !14
#   br label %B0.endif.endif.endif.endif
#
# B0.endif.endif.endif.endif:                       ; preds = %B68.i.i, %B40.i.i, %B12.i.i
#   %.214.inv = icmp sgt i64 %arg.a.1, 0
#   %spec.select = select i1 %.214.inv, i64 %arg.a.1, i64 0
#   br i1 %.214.inv, label %B68.lr.ph, label %B90.endif
#
# B68.lr.ph:                                        ; preds = %B0.endif.endif.endif.endif
#   switch i64 %.11.i, label %B68.preheader [
#     i64 1, label %B68.lr.ph.split.us
#     i64 2, label %B68.us182.preheader
#   ]
#
# B68.us182.preheader:                              ; preds = %B68.lr.ph
#   %4 = icmp sgt i64 %spec.select, 1
#   %5 = select i1 %4, i64 %arg.a.1, i64 1
#   %6 = icmp eq i32 %.53.0.ph, 1
#   br i1 %6, label %B68.us182.us.preheader, label %B68.us182.preheader572
#
# B68.us182.preheader572:                           ; preds = %B68.us182.preheader
#   br label %B68.us182
#
# B68.us182.us.preheader:                           ; preds = %B68.us182.preheader
#   %min.iters.check237 = icmp ult i64 %5, 64
#   br i1 %min.iters.check237, label %B68.us182.us.preheader476, label %vector.memcheck244
#
# vector.memcheck244:                               ; preds = %B68.us182.us.preheader
#   %scevgep239 = getelementptr i8, i8* %.6.i.i, i64 %5
#   %7 = shl i64 %5, 1
#   %scevgep240 = getelementptr i8, i8* %arg.a.0, i64 %7
#   %bound0241 = icmp ult i8* %.6.i.i, %scevgep240
#   %bound1242 = icmp ugt i8* %scevgep239, %arg.a.0
#   %found.conflict243 = and i1 %bound0241, %bound1242
#   br i1 %found.conflict243, label %B68.us182.us.preheader476, label %vector.ph245
#
# vector.ph245:                                     ; preds = %vector.memcheck244
#   %n.vec246 = and i64 %5, -64
#   %8 = add i64 %n.vec246, -64
#   %9 = lshr exact i64 %8, 6
#   %10 = add nuw nsw i64 %9, 1
#   %11 = icmp eq i64 %8, 0
#   br i1 %11, label %middle.block235.unr-lcssa, label %vector.ph245.new
#
# vector.ph245.new:                                 ; preds = %vector.ph245
#   %12 = lshr i64 %10, 1
#   %13 = mul nsw i64 %12, -2
#   br label %vector.body236
#
# vector.body236:                                   ; preds = %vector.body236, %vector.ph245.new
#   %lsr.iv1840 = phi i64 [ %lsr.iv.next1841, %vector.body236 ], [ %13, %vector.ph245.new ]
#   %index247 = phi i64 [ 0, %vector.ph245.new ], [ %index.next.1, %vector.body236 ]
#   %sunkaddr = mul i64 %index247, 2
#   %sunkaddr1849 = getelementptr i8, i8* %arg.a.0, i64 %sunkaddr
#   %14 = bitcast i8* %sunkaddr1849 to <16 x i16>*
#   %wide.load249 = load <16 x i16>, <16 x i16>* %14, align 2, !alias.scope !18, !noalias !21
#   %sunkaddr1850 = mul i64 %index247, 2
#   %sunkaddr1851 = getelementptr i8, i8* %arg.a.0, i64 %sunkaddr1850
#   %sunkaddr1852 = getelementptr i8, i8* %sunkaddr1851, i64 32
#   %15 = bitcast i8* %sunkaddr1852 to <16 x i16>*
#   %wide.load250 = load <16 x i16>, <16 x i16>* %15, align 2, !alias.scope !18, !noalias !21
#   %sunkaddr1853 = mul i64 %index247, 2
#   %sunkaddr1854 = getelementptr i8, i8* %arg.a.0, i64 %sunkaddr1853
# ...
#   %lsr.iv.next = add i64 %lsr.iv, 128
#   %690 = tail call { i64, i1 } @llvm.uadd.with.overflow.i64(i64 %lsr.iv619, i64 1)
#   %ov830 = extractvalue { i64, i1 } %690, 1
#   %lsr.iv.next620 = add i64 %lsr.iv619, 1
#   br i1 %ov830, label %middle.block272, label %vector.body274.epil, !llvm.loop !133
#
# middle.block272:                                  ; preds = %vector.body274.epil, %middle.block272.unr-lcssa
#   %cmp.n291 = icmp eq i64 %543, %n.vec287
#   br i1 %cmp.n291, label %B134, label %B104.endif.us.us.preheader296
#
# B104.endif.us.us.preheader296:                    ; preds = %middle.block272, %vector.memcheck284, %B104.endif.us.us.preheader
#   %.397.0114.us.us.ph = phi i64 [ 0, %vector.memcheck284 ], [ 0, %B104.endif.us.us.preheader ], [ %n.vec287, %middle.block272 ]
#   %691 = xor i64 %.397.0114.us.us.ph, -1
#   %692 = add i64 %543, %691
#   %xtraiter = and i64 %543, 7
#   %lcmp.mod.not = icmp eq i64 %xtraiter, 0
#   br i1 %lcmp.mod.not, label %B104.endif.us.us.prol.loopexit, label %B104.endif.us.us.prol.preheader
#
# B104.endif.us.us.prol.preheader:                  ; preds = %B104.endif.us.us.preheader296
#   %scevgep377 = getelementptr i8, i8* %.6.i.i, i64 %arg.a.1
#   br label %B104.endif.us.us.prol
#
# B104.endif.us.us.prol:                            ; preds = %B104.endif.us.us.prol, %B104.endif.us.us.prol.preheader
#   %.397.0114.us.us.prol = phi i64 [ %.466.us.us.prol, %B104.endif.us.us.prol ], [ %.397.0114.us.us.ph, %B104.endif.us.us.prol.preheader ]
#   %prol.iter = phi i64 [ %prol.iter.sub, %B104.endif.us.us.prol ], [ %xtraiter, %B104.endif.us.us.prol.preheader ]
#   %.466.us.us.prol = add nuw nsw i64 %.397.0114.us.us.prol, 1
#   %scevgep618 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us.prol
#   %.37.i.us.us214.prol = load i8, i8* %scevgep618, align 1, !noalias !64
#   %scevgep617 = getelementptr i8, i8* %scevgep377, i64 %.397.0114.us.us.prol
#   store i8 %.37.i.us.us214.prol, i8* %scevgep617, align 1, !noalias !67
#   %prol.iter.sub = add nsw i64 %prol.iter, -1
#   %prol.iter.cmp.not = icmp eq i64 %prol.iter.sub, 0
#   br i1 %prol.iter.cmp.not, label %B104.endif.us.us.prol.loopexit, label %B104.endif.us.us.prol, !llvm.loop !134
#
# B104.endif.us.us.prol.loopexit:                   ; preds = %B104.endif.us.us.prol, %B104.endif.us.us.preheader296
#   %.397.0114.us.us.unr = phi i64 [ %.397.0114.us.us.ph, %B104.endif.us.us.preheader296 ], [ %.466.us.us.prol, %B104.endif.us.us.prol ]
#   %693 = icmp ult i64 %692, 7
#   br i1 %693, label %B134, label %B104.endif.us.us.preheader321
#
# B104.endif.us.us.preheader321:                    ; preds = %B104.endif.us.us.prol.loopexit
#   %694 = add i64 %arg.a.1, 7
#   %scevgep360 = getelementptr i8, i8* %.6.i.i, i64 %694
#   br label %B104.endif.us.us
#
# B104.endif.us.us:                                 ; preds = %B104.endif.us.us, %B104.endif.us.us.preheader321
#   %.397.0114.us.us = phi i64 [ %.466.us.us.7, %B104.endif.us.us ], [ %.397.0114.us.us.unr, %B104.endif.us.us.preheader321 ]
#   %sunkaddr2437 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us
#   %.37.i.us.us214 = load i8, i8* %sunkaddr2437, align 1, !noalias !64
#   %scevgep614 = getelementptr i8, i8* %scevgep360, i64 %.397.0114.us.us
#   %scevgep615 = getelementptr i8, i8* %scevgep614, i64 -7
#   store i8 %.37.i.us.us214, i8* %scevgep615, align 1, !noalias !67
#   %sunkaddr2438 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us
#   %sunkaddr2439 = getelementptr i8, i8* %sunkaddr2438, i64 1
#   %.37.i.us.us214.1 = load i8, i8* %sunkaddr2439, align 1, !noalias !64
#   %scevgep612 = getelementptr i8, i8* %scevgep360, i64 %.397.0114.us.us
#   %scevgep613 = getelementptr i8, i8* %scevgep612, i64 -6
#   store i8 %.37.i.us.us214.1, i8* %scevgep613, align 1, !noalias !67
#   %sunkaddr2440 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us
#   %sunkaddr2441 = getelementptr i8, i8* %sunkaddr2440, i64 2
#   %.37.i.us.us214.2 = load i8, i8* %sunkaddr2441, align 1, !noalias !64
#   %scevgep610 = getelementptr i8, i8* %scevgep360, i64 %.397.0114.us.us
#   %scevgep611 = getelementptr i8, i8* %scevgep610, i64 -5
#   store i8 %.37.i.us.us214.2, i8* %scevgep611, align 1, !noalias !67
#   %sunkaddr2442 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us
#   %sunkaddr2443 = getelementptr i8, i8* %sunkaddr2442, i64 3
#   %.37.i.us.us214.3 = load i8, i8* %sunkaddr2443, align 1, !noalias !64
#   %scevgep608 = getelementptr i8, i8* %scevgep360, i64 %.397.0114.us.us
#   %scevgep609 = getelementptr i8, i8* %scevgep608, i64 -4
#   store i8 %.37.i.us.us214.3, i8* %scevgep609, align 1, !noalias !67
#   %sunkaddr2444 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us
#   %sunkaddr2445 = getelementptr i8, i8* %sunkaddr2444, i64 4
#   %.37.i.us.us214.4 = load i8, i8* %sunkaddr2445, align 1, !noalias !64
#   %scevgep606 = getelementptr i8, i8* %scevgep360, i64 %.397.0114.us.us
#   %scevgep607 = getelementptr i8, i8* %scevgep606, i64 -3
#   store i8 %.37.i.us.us214.4, i8* %scevgep607, align 1, !noalias !67
#   %sunkaddr2446 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us
#   %sunkaddr2447 = getelementptr i8, i8* %sunkaddr2446, i64 5
#   %.37.i.us.us214.5 = load i8, i8* %sunkaddr2447, align 1, !noalias !64
#   %scevgep604 = getelementptr i8, i8* %scevgep360, i64 %.397.0114.us.us
#   %scevgep605 = getelementptr i8, i8* %scevgep604, i64 -2
#   store i8 %.37.i.us.us214.5, i8* %scevgep605, align 1, !noalias !67
#   %sunkaddr2448 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us
#   %sunkaddr2449 = getelementptr i8, i8* %sunkaddr2448, i64 6
#   %.37.i.us.us214.6 = load i8, i8* %sunkaddr2449, align 1, !noalias !64
#   %scevgep602 = getelementptr i8, i8* %scevgep360, i64 %.397.0114.us.us
#   %scevgep603 = getelementptr i8, i8* %scevgep602, i64 -1
#   store i8 %.37.i.us.us214.6, i8* %scevgep603, align 1, !noalias !67
#   %.466.us.us.7 = add nuw nsw i64 %.397.0114.us.us, 8
#   %sunkaddr2450 = getelementptr i8, i8* %arg.b.0, i64 %.397.0114.us.us
#   %sunkaddr2451 = getelementptr i8, i8* %sunkaddr2450, i64 7
#   %.37.i.us.us214.7 = load i8, i8* %sunkaddr2451, align 1, !noalias !64
#   %scevgep616 = getelementptr i8, i8* %scevgep360, i64 %.397.0114.us.us
#   store i8 %.37.i.us.us214.7, i8* %scevgep616, align 1, !noalias !67
#   %exitcond229.not.7 = icmp eq i64 %543, %.466.us.us.7
#   br i1 %exitcond229.not.7, label %B134, label %B104.endif.us.us, !llvm.loop !135
#
# B104.endif.us118:                                 ; preds = %B104.endif.us118.preheader174, %B68.i.us134
#   %.397.0114.us120 = phi i64 [ %.466.us122, %B68.i.us134 ], [ 0, %B104.endif.us118.preheader174 ]
#   %695 = icmp eq i32 %.53.0.ph, 4
#   %.466.us122 = add nuw nsw i64 %.397.0114.us120, 1
#   br i1 %695, label %B68.i.us134, label %B0.if.if
#
# B68.i.us134:                                      ; preds = %B104.endif.us118
#   %696 = shl nuw i64 %.397.0114.us120, 1
#   %scevgep930 = getelementptr i8, i8* %arg.b.0, i64 %696
#   %scevgep930931 = bitcast i8* %scevgep930 to i16*
#   %.66.i.us130 = load i16, i16* %scevgep930931, align 2, !noalias !64
#   %.103.i.us135 = zext i16 %.66.i.us130 to i32
#   %697 = shl i64 %.397.0114.us120, 2
#   %scevgep928 = getelementptr i8, i8* %scevgep516, i64 %697
#   %scevgep928929 = bitcast i8* %scevgep928 to i32*
#   store i32 %.103.i.us135, i32* %scevgep928929, align 4, !noalias !67
#   %exitcond233.not = icmp eq i64 %405, %.466.us122
#   br i1 %exitcond233.not, label %B134, label %B104.endif.us118
#
# B104.endif.us149:                                 ; preds = %B104.endif.us149.preheader178, %B68.i.us162
#   %.397.0114.us151 = phi i64 [ %.466.us153, %B68.i.us162 ], [ 0, %B104.endif.us149.preheader178 ]
#   %698 = icmp eq i32 %.53.0.ph, 4
#   %.466.us153 = add nuw nsw i64 %.397.0114.us151, 1
#   br i1 %698, label %B68.i.us162, label %B0.if.if
#
# B68.i.us162:                                      ; preds = %B104.endif.us149
#   %699 = shl i64 %.397.0114.us151, 2
#   %scevgep1203 = getelementptr i8, i8* %arg.b.0, i64 %699
#   %scevgep12031204 = bitcast i8* %scevgep1203 to i32*
#   %.95.i.us157 = load i32, i32* %scevgep12031204, align 4, !noalias !64
#   %700 = shl i64 %.397.0114.us151, 2
#   %scevgep1201 = getelementptr i8, i8* %scevgep526, i64 %700
#   %scevgep12011202 = bitcast i8* %scevgep1201 to i32*
#   store i32 %.95.i.us157, i32* %scevgep12011202, align 4, !noalias !67
#   %exitcond235.not = icmp eq i64 %262, %.466.us153
#   br i1 %exitcond235.not, label %B134, label %B104.endif.us149
# }
#
# ; Function Attrs: nofree noinline norecurse nounwind
# define linkonce_odr void @NRT_incref(i8* %.1) local_unnamed_addr #0 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !7
#
# .3.if:                                            ; preds = %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   %.7 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw add i64* %.7, i64 1 monotonic
#   ret void
# }
#
# ; Function Attrs: noinline
# define linkonce_odr void @NRT_decref(i8* %.1) local_unnamed_addr #1 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !7
#
# .3.if:                                            ; preds = %.3.endif, %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   fence release
#   %.8 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw sub i64* %.8, i64 1 monotonic
#   %.10 = icmp eq i64 %.4.i, 1
#   br i1 %.10, label %.3.endif.if, label %.3.if, !prof !7
#
# .3.endif.if:                                      ; preds = %.3.endif
#   fence acquire
#   tail call void @NRT_MemInfo_call_dtor(i8* nonnull %.1)
#   ret void
# }
#
# declare noalias i8* @NRT_MemInfo_alloc_safe(i64) local_unnamed_addr
#
# ; Function Attrs: nounwind readnone speculatable willreturn
# declare { i64, i1 } @llvm.uadd.with.overflow.i64(i64, i64) #2
#
# declare void @NRT_MemInfo_call_dtor(i8*) local_unnamed_addr
#
# ; Function Attrs: argmemonly nounwind willreturn writeonly
# declare void @llvm.memset.p0i8.i64(i8* nocapture writeonly, i8, i64, i1 immarg) #3
#
# ; Function Attrs: nounwind
# declare void @llvm.stackprotector(i8*, i8**) #4
#
# attributes #0 = { nofree noinline norecurse nounwind }
# attributes #1 = { noinline }
# attributes #2 = { nounwind readnone speculatable willreturn }
# attributes #3 = { argmemonly nounwind willreturn writeonly }
# attributes #4 = { nounwind }
#
# !numba_args_may_always_need_nrt = !{!0, !1, !1, !2, !3, !4, !2, !2, !3, !4, !5, !5, !2, !3, !4}
#
# !0 = !{i32 ({ i8*, i64, i32, i32, i64, i8*, i8* }*, { i8*, i32, i8* }**, i8*, i64, i32, i32, i64, i8*, i8*, i8*, i64, i32, i32, i64, i8*, i8*)* @_ZN8__main__3addB2v4B44c8tJTIcFHzwl2ILiXkcBLaFgF0XXBPQ5mKUJAA_3d_3dE12unicode_type12unicode_type}
# !1 = !{i32 ({ i8*, i64, i32, i32, i64, i8*, i8* }*, { i8*, i32, i8* }**, i8*, i64, i32, i32, i64, i8*, i8*, i8*, i64, i32, i32, i64, i8*, i8*)* @_ZN5numba7cpython7unicode14unicode_concat12_3clocals_3e11concat_implB2v5B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dE12unicode_type12unicode_type}
# !2 = distinct !{null}
# !3 = distinct !{null}
# !4 = distinct !{null}
# !5 = distinct !{null}
# !6 = !{i1 true}
# !7 = !{!"branch_weights", i32 1, i32 99}
# !8 = !{!"branch_weights", i32 99, i32 1}
# !9 = !{!"branch_weights", i32 2126008812, i32 21474836}
# !10 = !{!11, !13}
# !11 = distinct !{!11, !12, !"_ZN5numba7cpython7unicode13_empty_stringB2v8B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dEixj: %retptr"}
# !12 = distinct !{!12, !"_ZN5numba7cpython7unicode13_empty_stringB2v8B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dEixj"}
# !13 = distinct !{!13, !12, !"_ZN5numba7cpython7unicode13_empty_stringB2v8B42c8tJTIcFHzwl2ILiXkcBV0KBSmNGHkyiCKJEEwA_3dEixj: %excinfo"}
# !14 = !{!15, !17, !11, !13}
# !15 = distinct !{!15, !16, !"_ZN5numba7cpython7unicode15_set_code_pointB3v10B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexj: %retptr"}
# !16 = distinct !{!16, !"_ZN5numba7cpython7unicode15_set_code_pointB3v10B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexj"}
# !17 = distinct !{!17, !16, !"_ZN5numba7cpython7unicode15_set_code_pointB3v10B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexj: %excinfo"}
# !18 = !{!19}
# !19 = distinct !{!19, !20}
# !20 = distinct !{!20, !"LVerDomain"}
# !21 = !{!22}
# !22 = distinct !{!22, !23, !"_ZN5numba7cpython7unicode15_get_code_pointB3v12B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typex: %retptr"}
# !23 = distinct !{!23, !"_ZN5numba7cpython7unicode15_get_code_pointB3v12B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typex"}
# !24 = !{!25}
# !25 = distinct !{!25, !20}
# !26 = !{!27, !29, !19}
# !27 = distinct !{!27, !28, !"_ZN5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx: %retptr"}
# !28 = distinct !{!28, !"_ZN5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx"}
# !29 = distinct !{!29, !28, !"_ZN5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx: %excinfo"}
# !30 = distinct !{!30, !31}
# !31 = !{!"llvm.loop.isvectorized", i32 1}
# !32 = !{!27, !29}
# !33 = distinct !{!33, !34}
# !34 = !{!"llvm.loop.unroll.disable"}
# !35 = distinct !{!35, !31}
# !36 = distinct !{!36, !34}
# !37 = !{!38}
# !38 = distinct !{!38, !39}
# !39 = distinct !{!39, !"LVerDomain"}
# !40 = !{!41}
# !41 = distinct !{!41, !39}
# !42 = !{!27, !29, !38}
# !43 = distinct !{!43, !31}
# !44 = !{!45}
# !45 = distinct !{!45, !46}
# !46 = distinct !{!46, !"LVerDomain"}
# !47 = !{!48}
# !48 = distinct !{!48, !46}
# !49 = !{!27, !29, !45}
# !50 = distinct !{!50, !31}
# !51 = distinct !{!51, !34}
# !52 = distinct !{!52, !31}
# !53 = distinct !{!53, !31}
# !54 = !{!55}
# !55 = distinct !{!55, !56}
# !56 = distinct !{!56, !"LVerDomain"}
# !57 = !{!58}
# !58 = distinct !{!58, !56}
# !59 = !{!27, !29, !55}
# !60 = distinct !{!60, !31}
# !61 = distinct !{!61, !34}
# !62 = distinct !{!62, !34}
# !63 = distinct !{!63, !31}
# !64 = !{!65}
# !65 = distinct !{!65, !66, !"_ZN5numba7cpython7unicode15_get_code_pointB3v12B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typex: %retptr"}
# !66 = distinct !{!66, !"_ZN5numba7cpython7unicode15_get_code_pointB3v12B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typex"}
# !67 = !{!68, !70}
# !68 = distinct !{!68, !69, !"_ZN5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx: %retptr"}
# !69 = distinct !{!69, !"_ZN5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx"}
# !70 = distinct !{!70, !69, !"_ZN5numba7cpython7unicode15_set_code_pointB3v13B38c8tJTIcFHzwl2ILiXkcBV0KBSmNGHlhCEwA_3dE12unicode_typexx: %excinfo"}
# !71 = distinct !{!71, !34}
# !72 = !{!73}
# !73 = distinct !{!73, !74}
# !74 = distinct !{!74, !"LVerDomain"}
# !75 = !{!76}
# !76 = distinct !{!76, !74}
# !77 = !{!68, !70, !73}
# !78 = distinct !{!78, !31}
# !79 = distinct !{!79, !34}
# !80 = !{!81}
# !81 = distinct !{!81, !82}
# !82 = distinct !{!82, !"LVerDomain"}
# !83 = !{!84}
# !84 = distinct !{!84, !82}
# !85 = !{!68, !70, !81}
# !86 = distinct !{!86, !31}
# !87 = distinct !{!87, !31}
# !88 = distinct !{!88, !31}
# !89 = distinct !{!89, !34}
# !90 = !{!91}
# !91 = distinct !{!91, !92}
# !92 = distinct !{!92, !"LVerDomain"}
# !93 = !{!94}
# !94 = distinct !{!94, !92}
# !95 = !{!68, !70, !91}
# !96 = distinct !{!96, !31}
# !97 = distinct !{!97, !34}
# !98 = distinct !{!98, !34}
# !99 = !{!100}
# !100 = distinct !{!100, !101}
# !101 = distinct !{!101, !"LVerDomain"}
# !102 = !{!103}
# !103 = distinct !{!103, !101}
# !104 = !{!68, !70, !100}
# !105 = distinct !{!105, !31}
# !106 = distinct !{!106, !31}
# !107 = distinct !{!107, !31}
# !108 = distinct !{!108, !34}
# !109 = !{!110}
# !110 = distinct !{!110, !111}
# !111 = distinct !{!111, !"LVerDomain"}
# !112 = !{!113}
# !113 = distinct !{!113, !111}
# !114 = !{!68, !70, !110}
# !115 = distinct !{!115, !31}
# !116 = !{!117}
# !117 = distinct !{!117, !118}
# !118 = distinct !{!118, !"LVerDomain"}
# !119 = !{!120}
# !120 = distinct !{!120, !118}
# !121 = !{!68, !70, !117}
# !122 = distinct !{!122, !31}
# !123 = distinct !{!123, !34}
# !124 = distinct !{!124, !31}
# !125 = distinct !{!125, !31}
# !126 = !{!127}
# !127 = distinct !{!127, !128}
# !128 = distinct !{!128, !"LVerDomain"}
# !129 = !{!130}
# !130 = distinct !{!130, !128}
# !131 = !{!68, !70, !127}
# !132 = distinct !{!132, !31}
# !133 = distinct !{!133, !34}
# !134 = distinct !{!134, !34}
# !135 = distinct !{!135, !31}

# %% [markdown]
# ## But there's a caveat
# Now, watch what happens when we try to do something that is natural in Python, but not particularly mathematically sound:

# %%
from numba import njit

# %%
def add_strings(a, b):
    return a + b

# %%
add_strings_jit = njit()(add_strings)

# %%
add_strings_jit('a', 'b')
# Out:
# 'ab'

# %%
@njit
def create_dict():
    a = [0, 1, (10,20), {"a":10}]
    return a

# %%
create_dict()[0]
# Out:
# <ipython-input-40-ee656fbaf83e>:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function create_dict failed at nopython mode lowering due to: unhashable type: 'list'
#   @jit
# /usr/local/lib/python3.10/dist-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "create_dict" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-40-ee656fbaf83e>", line 2:
# @jit
# def create_dict():
# ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /usr/local/lib/python3.10/dist-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-40-ee656fbaf83e>", line 2:
# @jit
# def create_dict():
# ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# 0

# %%
add_strings_jit.inspect_types()
# Out:
# add_strings (unicode_type, unicode_type)
# --------------------------------------------------------------------------------
# # File: <ipython-input-24-d1008a9d4aa2>
# # --- LINE 1 ---
# # label 0
#
# def add_strings(a, b):
#
#     # --- LINE 2 ---
#     #   a = arg(0, name=a)  :: unicode_type
#     #   b = arg(1, name=b)  :: unicode_type
#     #   $0.3 = a + b  :: unicode_type
#     #   del b
#     #   del a
#     #   $0.4 = cast(value=$0.3)  :: unicode_type
#     #   del $0.3
#     #   return $0.4
#
#     return a + b
#
#
# ================================================================================

# %%
@jit(int64, int64)

# %%
@njit(cache=True)
def minus(a, b):
    return a-b

# %%
minus(10., 20.)
# Out:
# -10.0

# %% [markdown]
# ### Compiler options
#
# ```python
# cache=True
# ```
#
# if you don't want to always want to get dinged by the compilation time for every run. This will actually save the compiled function into something like a `pyc` file in your `__pycache__` directory, so even between sessions you should have nice fast performance.

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Nov 14 14:32 .
# drwxr-xr-x 1 root root 4096 Nov 16 14:12 ..
# drwxr-xr-x 4 root root 4096 Nov 14 14:31 .config
# drwxr-xr-x 1 root root 4096 Nov 14 14:32 sample_data

# %% [markdown]
# ## N-Body problems
#
# Many physical problems require the evaluation of all pairwise interactions of a large number of particles, so-called N-body problems. These problems arise in molecular dynamics, astrodynamics and electromagnetics among others.
#
# Their pairwise interactions can be expressed as:
#
# \begin{equation}
# f_i = \sum_{j=1}^n{P \left(\boldsymbol{x}_i, \boldsymbol{x}_j \right)w_j} \ \ \ \text{for } i=1,2,...,n
# \end{equation}
#
# *  where subscripts $i$,  $j$ respectively denote *target* and *source*
# *  $f_i$ can be a *potential* (or *force*) at target point $i$
# *  $w_j$ is the *source weight*
# *  $\boldsymbol{x}_i, \boldsymbol{x}_j$ are the *spatial positions* of particles
# *  $P \left(\boldsymbol{x}_i, \boldsymbol{x}_j \right)$ is the *interaction kernel*.
#
# In order to evalute the potential $f_i$ at a target point $i$, we have to loop over each source particle $j$. Since there are $n$ target points $i$, this 'brute-force' approach costs $\mathcal{O} \left(n^2 \right)$ operations.
#
# One possible approach in this kind of problem is to define a few classes, say `Point` and `Particle` and then loop over the objects and perform the necessary point-to-point calculations.

# %%
class Point():
    """
    Arguments:
        domain: the domain of random generated coordinates x,y,z,
                default=1.0

    Attributes:
        x, y, z: coordinates of the point
    """
    def __init__(self, domain=1.0):
        self.x = domain * numpy.random.random()
        self.y = domain * numpy.random.random()
        self.z = domain * numpy.random.random()

    def distance(self, other):
        return ((self.x - other.x)**2 +
                (self.y - other.y)**2 +
                (self.z - other.z)**2)**.5

# %%
Barnes-Hut

# %%
class Particle(Point):
    """
    Attributes:
        m: mass of the particle
        phi: the potential of the particle
    """

    def __init__(self, domain=1.0, m=1.0):
        Point.__init__(self, domain)
        self.m = m
        self.phi = 0.

# %% [markdown]
# Now we create a list of `n` random particles, define a function to calculate their interaction via direct summation and run!

# %%
n = 1000
particles = [Particle(m = 1 / n) for i in range(n)]

# %%
particles[10].m
# Out:
# 0.001

# %%
def direct_sum(particles):
    """
    Calculate the potential at each particle
    using direct summation method.

    Arguments:
        particles: the list of particles

    """
    for i, target in enumerate(particles):
        for source in (particles[:i] + particles[i+1:]):
            r = target.distance(source)
            target.phi += source.m / r

# %%
direct_sum(particles)

# %%
orig_time = %timeit -o direct_sum(particles)
# Out:
# 602 ms ± 9.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %load_ext line_profiler

# %%
# %lprun -f direct_sum direct_sum(particles)

# %% [markdown]
# ## How do we use Numba on this problem?
# Problem: Numba doesn't support jitting native Python classes.  There is a `jit_class` structure in Numba but it's still in early development.
#
# But it's nice to have attributes for literate programming.
#
# Solution: NumPy custom dtypes.

# %%
particle_dtype = numpy.dtype({'names':['x','y','z','m','phi'],
                             'formats':[numpy.double,
                                        numpy.double,
                                        numpy.double,
                                        numpy.double,
                                        numpy.double]})

# %%
myarray = numpy.ones(3, dtype=particle_dtype)

# %%
myarray[0]["z"]
# Out:
# 1.0

# %%
myarray['x']=numpy.ones(3)*10

# %%
myarray
# Out:
# array([(10., 1., 1., 1., 1.), (10., 1., 1., 1., 1.),
#        (10., 1., 1., 1., 1.)],
#       dtype=[('x', '<f8'), ('y', '<f8'), ('z', '<f8'), ('m', '<f8'), ('phi', '<f8')])

# %% [markdown]
# ### Exercise 1
#
# Write a function `create_n_random_particles` that takes the arguments `n` (number of particles), `m` (mass of every particle) and a domain within to generate a random number (as in the class above).
# It should create an array with `n` elements and `dtype=particle_dtype` and then return that array.
#
# For each particle, the mass should be initialized to the value of `m` and the potential `phi` initialized to zero.
#
# For the `x` component of a given particle `p`, you might do something like
#
# ```python
# p['x'] = domain * numpy.random.random()
# ```

# %%
@njit
def create_n_random_particles(n, m, domain=1):
    '''
    Creates `n` particles with mass `m` with random coordinates
    between 0 and `domain`
    '''
    parts = numpy.zeros((n), dtype=particle_dtype)


    parts['x'] = numpy.random.random(m)*domain
    ### your code
    ### your code
    ### your code

    return parts   #parts is an array of particles

# %%
# test it
parts = create_n_random_particles(1000, .001, 1)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-74-b779263aaa3d> in <module>
#       1 # test it
# ----> 2 parts = create_n_random_particles(1000, .001, 1)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numba/dispatcher.py in _compile_for_args(self, *args, **kws)
#     374                 e.patch_message(msg)
#     375
# --> 376             error_rewrite(e, 'typing')
#     377         except errors.UnsupportedError as e:
#     378             # Something unsupported is present in the user code, add help info
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numba/dispatcher.py in error_rewrite(e, issue_type)
#     341                 raise e
#     342             else:
# --> 343                 reraise(type(e), e, None)
#     344
#     345         argtypes = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numba/six.py in reraise(tp, value, tb)
#     656             value = tp()
#     657         if value.__traceback__ is not tb:
# --> 658             raise value.with_traceback(tb)
#     659         raise value
#     660
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Invalid use of Function(np.random.random) with argument(s) of type(s): (float64)
# Known signatures:
#  * () -> float64
#  * parameterized
# In definition 0:
#     TypeError: object of type 'Float' has no len()
#     raised from /Users/sergey/opt/anaconda3/lib/python3.7/site-packages/numba/typing/randomdecl.py:38
# In definition 1:
#     TypeError: object of type 'Float' has no len()
#     raised from /Users/sergey/opt/anaconda3/lib/python3.7/site-packages/numba/typing/randomdecl.py:38
# This error is usually caused by passing an argument of a type that is unsupported by the named function.
# [1] During: resolving callee type: Function(np.random.random)
# [2] During: typing of call at <ipython-input-73-2e691807810d> (10)
#
#
# File "<ipython-input-73-2e691807810d>", line 10:
# def create_n_random_particles(n, m, domain=1):
#     <source elided>
#
#     parts['x'] = numpy.random.random(m)*domain
#     ^
#
# This is not usually a problem with Numba itself but instead often caused by
# the use of unsupported features or an issue in resolving types.
#
# To see Python/NumPy features supported by the latest release of Numba visit:
# http://numba.pydata.org/numba-doc/latest/reference/pysupported.html
# and
# http://numba.pydata.org/numba-doc/latest/reference/numpysupported.html
#
# For more information about typing errors and how to debug them visit:
# http://numba.pydata.org/numba-doc/latest/user/troubleshoot.html#my-code-doesn-t-compile
#
# If you think your code should work with Numba, please report the error message
# and traceback, along with a minimal reproducer at:
# https://github.com/numba/numba/issues/new

# %% [markdown]
# ### Exercise 2
#
# Write a JITted function `distance` to calculate the distance between two particles of dtype `particle_dtype`
#
# Here's the `distance` method from the `Particle` class as a reference:
#
# ```python
# def distance(self, other):
#         return ((self.x - other.x)**2 +
#                 (self.y - other.y)**2 +
#                 (self.z - other.z)**2)**.5
# ```

# %%
def distance(part1, part2):
    '''calculate the distance between two particles'''

    # your code here

# %%
# test it

distance(parts[0], parts[1])

# %% [markdown]
# ### Exercise 3
# Modify the original `direct_sum` function (copied below for reference) to instead work a NumPy array of particles.  Loop over each element in the array and calculate its total potential.
#
# ```python
# def direct_sum(particles):
#     """
#     Calculate the potential at each particle
#     using direct summation method.
#
#     Arguments:
#         particles: the list of particles
#
#     """
#     for i, target in enumerate(particles):
#         for source in (particles[:i] + particles[i+1:]):
#             r = target.distance(source)
#             target.phi += source.m / r

# %%
def direct_sum(particles):
    # take it away
